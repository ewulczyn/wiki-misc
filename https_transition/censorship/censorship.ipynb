# %%
from db_utils import query_hive_ssh, execute_hive_expression, get_hive_timespan
from censorship import *
import pandas as pd
% matplotlib inline
# Out:
# Vendor:  Continuum Analytics, Inc.
# Package: mkl
# Message: trial mode expires in 28 days

# %% [markdown]
# # Generate Data Set

# %%
def get_PVSpanComparison_df(pvsc):
    """
    Pull a dataframe with articles that jumped
    at least one standard deviation in view proportion
    """
    query = """
    SELECT *,
    (post_n_tpc / 3 - pre_n_tpc) / pre_n_tpc as clean_tpc_view_delta
    FROM %(db)s.%(span_table)s
    WHERE post_n_tpc > 300
    AND pre_n_wd > 1000
    AND (post_n_tpc / 3 - pre_n_tpc) / pre_n_tpc > 2.0
    """
    df = query_hive_ssh(query % pvsc.params, 'get_PVSpanComparison_df', priority = True)
    df.columns = [c.split('.')[1] if len(c.split('.')) == 2 else c for c in df.columns]
    df.sort('normalized_tpc_view_proportion_delta', inplace  = True, ascending = 0)
    return df

# %%
# create a comparison between two time periods before the https trnasiton
cmp_ctr = PVSpanComparison(['2015-05-01', '2015-05-14'], ['2015-05-15', '2015-05-28'], 'censorship', dry = True)
# create a comparison between two weeks before and several weeks after the https transition
cmp = PVSpanComparison(['2015-05-15', '2015-05-28'], ['2015-06-17', '2015-07-30'], 'censorship', dry = True)

# %%
# pull reduced data from Hive into local pandas df
df = get_PVSpanComparison_df(cmp)
df_ctr = get_PVSpanComparison_df(cmp_ctr)

# %% [markdown]
# # Investigate Top Articles per Country

# %%
df.sort('clean_tpc_view_delta', inplace  = True, ascending = 0)

# %%
country = 'Bahrain'
cols = ['p', 't', 'c', 'en_page_title', 'clean_tpc_view_delta', 'normalized_tpc_view_proportion_delta', 'pre_n_tpc', 'post_n_tpc',  ]
df[df['c'] == country][cols].head(100)
# Out:
#                    p                                           t        c  \
# 213485  en.wikipedia                                 Yakub_Memon  Bahrain
# 158907  bg.wikipedia                            Начална_страница  Bahrain
# 228356  en.wikipedia                                 Eid_Mubarak  Bahrain
# 31270   ar.wikipedia     عبد_الله_بن_عبد_العزيز_بن_مساعد_آل_سعود  Bahrain
# 10334   ar.wikipedia                              محرك_نفاث_عنفي  Bahrain
# 162300  en.wikipedia               Indian_Idol_Junior_(season_2)  Bahrain
# 221402  ar.wikipedia                                صلاة_العيدين  Bahrain
# 120009  en.wikipedia                                   Ruby_Rose  Bahrain
# 182055  en.wikipedia                Rainbow_flag_(LGBT_movement)  Bahrain
# 123389  ar.wikipedia                                    يوم_الأب  Bahrain
# 7581    en.wikipedia  Flags_of_the_Confederate_States_of_America  Bahrain
# 44767   ar.wikipedia                                باريس_هيلتون  Bahrain
# 18703   ar.wikipedia                             قائمة_مدن_سورية  Bahrain
# 22579   en.wikipedia                                  Arda_Turan  Bahrain
# 177517  en.wikipedia                               Jules_Bianchi  Bahrain
# 96670   en.wikipedia                         Mark_Beech_(writer)  Bahrain
# 26443   ar.wikipedia                                      حيثيون  Bahrain
# 72054   en.wikipedia                  MasterChef_(U.S._season_4)  Bahrain
# 136482  ar.wikipedia               قائمة_أقدم_الجامعات_في_العالم  Bahrain
# 113184  en.wikipedia                               Sergio_Romero  Bahrain
# 178866  en.wikipedia       Saud_bin_Faisal_bin_Abdulaziz_Al_Saud  Bahrain
# 97323   id.wikipedia                               Halaman_Utama  Bahrain
# 98003   ar.wikipedia                                    حق_النقض  Bahrain
# 229929  en.wikipedia                                 The_Gallows  Bahrain
# 182290  ar.wikipedia                                 كيوي_(طائر)  Bahrain
# 90345   ar.wikipedia                               صلاة_التراويح  Bahrain
# 240439  en.wikipedia           Phir_Bhi_Na_Maane...Badtameez_Dil  Bahrain
# 72176   en.wikipedia                                    Ratheesh  Bahrain
# 59301   en.wikipedia                     K._V._Vijayendra_Prasad  Bahrain
# 143267  ar.wikipedia                                أحمد_السلمان  Bahrain
# ...              ...                                         ...      ...
# 41821   ar.wikipedia                                 نور_الغندور  Bahrain
# 104801  ar.wikipedia                                  سامي_العدل  Bahrain
# 165858  ar.wikipedia                                محمد_الغزالي  Bahrain
# 226796  en.wikipedia                         Morgan_Schneiderlin  Bahrain
# 217441  en.wikipedia                         Battleground_(2015)  Bahrain
# 195170  ar.wikipedia                             عبد_الله_بالخير  Bahrain
# 162842  en.wikipedia                           Alphonse_Putharen  Bahrain
# 19148   en.wikipedia       List_of_highest-grossing_Indian_films  Bahrain
# 226497  en.wikipedia                                Ivanka_Trump  Bahrain
# 181161  ar.wikipedia                                   ياسر_جلال  Bahrain
# 82463   ar.wikipedia                                 حلا_(ممثلة)  Bahrain
# 214400  ar.wikipedia                                      بيرانا  Bahrain
# 2951    ar.wikipedia                                 ريماس_منصور  Bahrain
# 40457   en.wikipedia                                      Premam  Bahrain
# 236919  ar.wikipedia                                  زكاة_الفطر  Bahrain
# 18456   en.wikipedia                    The_Celebrity_Apprentice  Bahrain
# 189398  ar.wikipedia                                   عفاف_شعيب  Bahrain
# 201027  en.wikipedia                              Minions_(film)  Bahrain
# 29727   en.wikipedia                        Drishyam_(2015_film)  Bahrain
# 112074  en.wikipedia                                New_Horizons  Bahrain
# 149708  ar.wikipedia           تركي_الفيصل_بن_عبد_العزيز_آل_سعود  Bahrain
# 166666  en.wikipedia                                      Sense8  Bahrain
# 52290   en.wikipedia                                       Iftar  Bahrain
# 188992  en.wikipedia                                     Prabhas  Bahrain
# 186017  en.wikipedia                                       Ted_2  Bahrain
# 204704  ar.wikipedia                             نادين_نسيب_نجيم  Bahrain
# 93194   en.wikipedia                                Father's_Day  Bahrain
# 97861   en.wikipedia                          Terminator_Genisys  Bahrain
# 135036  en.wikipedia                       Mr._Robot_(TV_series)  Bahrain
# 72493   ar.wikipedia                          توماس_إدوارد_لورنس  Bahrain
#
#                                             en_page_title  \
# 213485                                        Yakub_Memon
# 158907                                          Main_Page
# 228356                                        Eid_Mubarak
# 31270                                                 NaN
# 10334                                            Turbojet
# 162300                      Indian_Idol_Junior_(season_2)
# 221402                                        Eid_prayers
# 120009                                          Ruby_Rose
# 182055                       Rainbow_flag_(LGBT_movement)
# 123389                                       Father's_Day
# 7581           Flags_of_the_Confederate_States_of_America
# 44767                                        Paris_Hilton
# 18703                             List_of_cities_in_Syria
# 22579                                          Arda_Turan
# 177517                                      Jules_Bianchi
# 96670                                 Mark_Beech_(writer)
# 26443                                            Hittites
# 72054                          MasterChef_(U.S._season_4)
# 136482  List_of_oldest_universities_in_continuous_oper...
# 113184                                      Sergio_Romero
# 178866              Saud_bin_Faisal_bin_Abdulaziz_Al_Saud
# 97323                                           Main_Page
# 98003                                                Veto
# 229929                                        The_Gallows
# 182290                                               Kiwi
# 90345                                             Tarawih
# 240439                  Phir_Bhi_Na_Maane...Badtameez_Dil
# 72176                                            Ratheesh
# 59301                             K._V._Vijayendra_Prasad
# 143267                                                NaN
# ...                                                   ...
# 41821                                                 NaN
# 104801                                                NaN
# 165858                                Mohammed_al-Ghazali
# 226796                                Morgan_Schneiderlin
# 217441                                Battleground_(2015)
# 195170                                                NaN
# 162842                                  Alphonse_Putharen
# 19148               List_of_highest-grossing_Indian_films
# 226497                                       Ivanka_Trump
# 181161                                                NaN
# 82463                                                 NaN
# 214400                                            Piranha
# 2951                                                  NaN
# 40457                                              Premam
# 236919                                      Zakat_al-Fitr
# 18456                            The_Celebrity_Apprentice
# 189398                                                NaN
# 201027                                     Minions_(film)
# 29727                                Drishyam_(2015_film)
# 112074                                       New_Horizons
# 149708                           Turki_bin_Faisal_Al_Saud
# 166666                                             Sense8
# 52290                                               Iftar
# 188992                                            Prabhas
# 186017                                              Ted_2
# 204704                                                NaN
# 93194                                        Father's_Day
# 97861                                  Terminator_Genisys
# 135036                              Mr._Robot_(TV_series)
# 72493                                      T._E._Lawrence
#
#         clean_tpc_view_delta  normalized_tpc_view_proportion_delta  pre_n_tpc  \
# 213485            432.166667                              5.294950          2
# 158907            415.666667                             12.881844          1
# 228356            271.333333                              4.476766          1
# 31270             107.666667                              6.483884          1
# 10334             107.333333                              5.915399          1
# 162300             82.500000                              6.573423          2
# 221402             76.777778                              4.335378          3
# 120009             63.833333                              1.646020          6
# 182055             49.500000                              1.668557          2
# 123389             47.250000                              0.885202          4
# 7581               45.666667                              0.620229          6
# 44767              43.727273                              1.675268         22
# 18703              41.000000                              2.491078          8
# 22579              40.000000                              1.966092          6
# 177517             39.583333                              1.362153          4
# 96670              38.190476                              2.212975          7
# 26443              37.250000                              8.379314          4
# 72054              36.875000                              0.319426          8
# 136482             35.555556                              5.464551          3
# 113184             35.555556                              0.881560          3
# 178866             35.000000                              1.838791          8
# 97323              34.395833                              1.590493         16
# 98003              34.333333                              5.831315          3
# 229929             33.555556                              3.446858          3
# 182290             32.333333                              0.438670          4
# 90345              30.395833                              1.644324         16
# 240439             28.476190                              0.382468          7
# 72176              27.733333                              5.281079          5
# 59301              27.200000                              2.506154          5
# 143267             27.166667                              0.867612         36
# ...                      ...                                   ...        ...
# 41821              12.522388                              1.063508         67
# 104801             12.242424                              0.270976         22
# 165858             11.755556                              5.473086         15
# 226796             11.600000                              0.430799         10
# 217441             11.534591                             -0.104231         53
# 195170             11.235294                              0.586543         17
# 162842             11.088889                              1.780810         30
# 19148              10.935484                              0.942742         31
# 226497             10.533333                              1.159670         10
# 181161             10.508772                              1.091531         19
# 82463              10.437500                              2.836483         16
# 214400             10.256410                              2.576572         13
# 2951               10.215686                              1.065971         17
# 40457              10.179487                              0.638244        156
# 236919             10.130952                             -0.188208         28
# 18456               9.769231                              0.112998         13
# 189398              9.527778                              1.796111         12
# 201027              9.496124                              0.600133         43
# 29727               9.266667                              2.226712         30
# 112074              9.214286                              0.176145         14
# 149708              9.000000                              4.313123         14
# 166666              9.000000                              0.396285         14
# 52290               9.000000                              0.006939         20
# 188992              8.662037                              1.084915         72
# 186017              8.565217                              0.240153         23
# 204704              8.452381                              1.828841         28
# 93194               8.389744                              0.509348         65
# 97861               8.287879                              0.220122         66
# 135036              8.138889                              0.295143         24
# 72493               8.062500                              3.358388         16
#
#         post_n_tpc
# 213485        2599
# 158907        1250
# 228356         817
# 31270          326
# 10334          325
# 162300         501
# 221402         700
# 120009        1167
# 182055         303
# 123389         579
# 7581           840
# 44767         2952
# 18703         1008
# 22579          738
# 177517         487
# 96670          823
# 26443          459
# 72054          909
# 136482         329
# 113184         329
# 178866         864
# 97323         1699
# 98003          318
# 229929         311
# 182290         400
# 90345         1507
# 240439         619
# 72176          431
# 59301          423
# 143267        3042
# ...            ...
# 41821         2718
# 104801         874
# 165858         574
# 226796         378
# 217441        1993
# 195170         624
# 162842        1088
# 19148         1110
# 226497         346
# 181161         656
# 82463          549
# 214400         439
# 2951           572
# 40457         5232
# 236919         935
# 18456          420
# 189398         379
# 201027        1354
# 29727          924
# 112074         429
# 149708         420
# 166666         420
# 52290          600
# 188992        2087
# 186017         660
# 204704         794
# 93194         1831
# 97861         1839
# 135036         658
# 72493          435
#
# [100 rows x 8 columns]

# %%
df[]

# %% [markdown]
# # Check Individual Articles
#
# Check if an article was trending up during the https transition.

# %%
article = 'Anal_sex'

# %%
df[df['t'] == article][cols].head(30)
# Out:
#                    p         t       c en_page_title  clean_tpc_view_delta  \
# 176144  en.wikipedia  Anal_sex    Iran      Anal_sex             13.072917
# 176143  en.wikipedia  Anal_sex  France      Anal_sex              9.667634
#
#         normalized_tpc_view_proportion_delta  pre_n_tpc  post_n_tpc
# 176144                             12.819376        224        9457
# 176143                              5.186167       1034       33091

# %%
df_ctr[df_ctr['en_page_title'] == article][cols].head(30)
# Out:
# Empty DataFrame
# Columns: [p, t, c, en_page_title, clean_tpc_view_delta, normalized_tpc_view_proportion_delta, pre_n_tpc, post_n_tpc]
# Index: []

# %% [markdown]
# # Save to File

# %%
def save_PVSpanComparison_df(df, fname):
    df_clean = df[['p', 't', 'c', 'id', 'en_page_title', 'tpc_view_delta']]
    df_clean.columns = ['project', 'title', 'country', 'wikidata_id', 'en_title', 'tpc_view_delta']
    df_clean.to_csv(fname, encoding = 'utf8', sep = '\t', index = False)

# %%
save_PVSpanComparison_df(df, './data/https_transition_comparison.tsv')
save_PVSpanComparison_df(df_ctr, './data/control_comparison.tsv')

# %%
d_censorship = pd.read_csv('./data/https_transition_comparison.tsv', sep = '\t', encoding = 'utf8')

# %%
d_censorship[d_censorship['en_title'] == 'Thor']
# Out:
#              project         title          country wikidata_id en_title  \
# 17098   cs.wikipedia          Thór    United States      Q42952     Thor
# 99481   fa.wikipedia  ثور_(اساطیر)             Iran      Q42952     Thor
# 129280  en.wikipedia          Thor          Austria      Q42952     Thor
# 207447  sk.wikipedia          Thor  Slovak Republic      Q42952     Thor
#
#         normalized_wikidata_view_proportion_delta  \
# 17098                                   -0.475413
# 99481                                    3.819679
# 129280                                   1.262351
# 207447                                   2.286280
#
#         normalized_article_view_proportion_delta
# 17098                                   5.898402
# 99481                                   2.565641
# 129280                                  2.165867
# 207447                                  1.533235

# %%
d_censorship[d_censorship['country'] == 'Iran']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-c1521c2bbe6a> in <module>()
# ----> 1 d_censorship[d_censorship['country'] == 'Iran']['tpc_view_proportion_delta']
#
# /Users/ellerywulczyn/miniconda3/lib/python3.4/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1795             return self._getitem_multilevel(key)
#    1796         else:
# -> 1797             return self._getitem_column(key)
#    1798
#    1799     def _getitem_column(self, key):
#
# /Users/ellerywulczyn/miniconda3/lib/python3.4/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    1802         # get column
#    1803         if self.columns.is_unique:
# -> 1804             return self._get_item_cache(key)
#    1805
#    1806         # duplicate columns & possible reduce dimensionaility
#
# /Users/ellerywulczyn/miniconda3/lib/python3.4/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1082         res = cache.get(item)
#    1083         if res is None:
# -> 1084             values = self._data.get(item)
#    1085             res = self._box_item_values(item, values)
#    1086             cache[item] = res
#
# /Users/ellerywulczyn/miniconda3/lib/python3.4/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    2849
#    2850             if not isnull(item):
# -> 2851                 loc = self.items.get_loc(item)
#    2852             else:
#    2853                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /Users/ellerywulczyn/miniconda3/lib/python3.4/site-packages/pandas/core/index.py in get_loc(self, key, method)
#    1570         """
#    1571         if method is None:
# -> 1572             return self._engine.get_loc(_values_from_object(key))
#    1573
#    1574         indexer = self.get_indexer([key], method=method)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:3824)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:3704)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12280)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12231)()
#
# KeyError: 'tpc_view_proportion_delta'
