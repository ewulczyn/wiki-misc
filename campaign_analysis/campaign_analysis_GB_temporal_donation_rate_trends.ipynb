# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import matplotlib.pyplot as plt
pd.options.display.mpl_style = 'default'

from campaign_analysis import *

# %%
start = '2014-11-28 00:00'
stop = '2015-01-03 08:00'

don = get_donations(start, stop, country = 'GB')
imp = get_impressions(start, stop, country_id = 11)
# Out:
#    amount   n                                        name      timestamp
# 0  239.68  11  B14_1120_enWW_dsk_tx_ev C14_enWW_dsk_lw_FR  2014-11-28 00
# 1   78.83  10  B14_1120_enWW_dsk_tx_tw C14_enWW_dsk_lw_FR  2014-11-28 00
# 2    7.88   1  B14_1120_enWW_dsk_tx_ev C14_enWW_dsk_lw_FR  2014-11-28 01
# 3   85.15   7  B14_1120_enWW_dsk_tx_tw C14_enWW_dsk_lw_FR  2014-11-28 01
# 4   20.50   2  B14_1120_enWW_dsk_tx_ev C14_enWW_dsk_lw_FR  2014-11-28 02

# %%
don['weekday'] = don.index.weekday
don['hour'] = (don.index.hour + 1) % 24
imp['weekday'] = imp.index.weekday
imp['hour'] = (imp.index.hour + 1) % 24

# %%
desk_regs = {
    'Large Desk': '.*5C_lg.* C14_en5C_dec_dsk_FR',
    'Top Desk': '.*5C_tp.* C14_en5C_dec_dsk_FR',
}

# %%
mob_regs = {
    'Large Mobile': '.*_lg.* C14_en5C_dec_mob_FR',
    'Top Mobile': '.*_tp.* C14_en5C_dec_mob_FR'
}

ipd_regs = {
    'Large Ipad': '.*_lg.* C14_en5C_dec_ipd_FR',
    'Top Ipad': '.*_tp.* C14_en5C_dec_ipd_FR'
}

# %%
config = {
            'hours' :3, 
            'stop': '2015-01-01 00',
        }

plot_rate_by_time(don, imp, desk_regs, **config)

# %% [markdown]
# #Weekly Donation Rates: GB Desktop

# %%
config = {
            'start' : '2014-12-01 00:00',
            'stop' : '2014-12-08 000:00',
            'ylabel': 'donation rate',
            'hours': 1
}

plot_rate_by_time(don, imp, {'Large Desk': '.*5C_lg.* C14_en5C_dec_dsk_FR'}, **config )
plot_rate_by_time(don, imp, {'Top Desk': '.*5C_tp.* C14_en5C_dec_dsk_FR'}, **config )

# %% [markdown]
# The Launch week shows a strong daily pattern but no particular weekly pattern. Possibly a decline from wednesday through Friday and a bump over the weekend.

# %%
config = {
            'start' : '2014-12-08 00:00',
            'stop' : '2014-12-015 000:00',
            'ylabel': 'donat',
            'hours': 1,
}

plot_rate_by_time(don, imp, {'Large Desk': '.*5C_lg.* C14_en5C_dec_dsk_FR'}, **config )
plot_rate_by_time(don, imp, {'Top Desk': '.*5C_tp.* C14_en5C_dec_dsk_FR'}, **config )

config = {
            'start' : '2014-12-22 00:00',
            'stop' : '2014-12-29 00:00',
            'ylabel': 'donation rate',
            'index': 'hour'
}
plot_rate_by_time(don, imp, {'Top Desk': '.*5C_tp.* C14_en5C_dec_dsk_FR'}, **config )

# %% [markdown]
# For the second week, it appears as if weekday donation rates are flat monday through Thursday, increase on Friday and then peak on the weekend.

# %%
config = {
            'start' : '2014-12-15 00:00',
            'stop' : '2014-12-22 000:00',
            'ylabel': 'donat',
            'hours': 1
}

plot_rate_by_time(don, imp, {'Large Desk': '.*5C_lg.* C14_en5C_dec_dsk_FR'}, **config )
plot_rate_by_time(don, imp, {'Top Desk': '.*5C_tp.* C14_en5C_dec_dsk_FR'}, **config )

# %% [markdown]
# This week there where all sorts of cookie changes that disturb the data.

# %%
config = {
            'start' : '2014-12-22 00:00',
            'stop' : '2014-12-29 000:00',
            'ylabel': 'donat',
            'hours': 2
}

plot_rate_by_time(don, imp, {'Large Desk': '.*5C_lg.* C14_en5C_dec_dsk_FR'}, **config )
plot_rate_by_time(don, imp, {'Top Desk': '.*5C_tp.* C14_en5C_dec_dsk_FR'}, **config )

config = {
            'start' : '2014-12-22 00:00',
            'stop' : '2014-12-29 00:00',
            'ylabel': 'donation rate',
            'index': 'hour'
}
plot_rate_by_time(don, imp, {'Top Desk': '.*5C_tp.* C14_en5C_dec_dsk_FR'}, **config )

# %% [markdown]
# This weeks again shows an increase from Monday to Thurday, a bump on Friday and then an dip on the wekeend. For this weekend the increase over the weekday average was pretty small compared to other weeks, maybe due to holidays.
#
# The donation rate increases rapidly from 5-8 UTC+1 and falls more gradually from 8-17 UTC+1. It rebounds at around 17-19 UTC+1 and then falls.
#
# When the limit banners to 5, we should make use of this information. We need to balance showing banners at high donation probability times with maximizing the number of unique clients we reach and the number of times we reach them. This kind of analysis will require a unique tokens. In general, we should start thinking about when to show banners in terms of time of day and lag between pageviews.

# %% [markdown]
# #Weekly Donation Rates: GB Mobile

# %%
config = {
            'start' : '2014-12-22 00:00',
            'stop' : '2014-12-29 00:00',
            'ylabel': 'donat',
            'hours': 1
}

plot_rate_by_time(don, imp, {'Large Mob': '.*_lg.* C14_en5C_dec_mob_FR'}, **config )
plot_rate_by_time(don, imp, {'Top Mob': '.*_tp.* C14_en5C_dec_mob_FR'}, **config )

config = {
            'start' : '2014-12-22 00:00',
            'stop' : '2014-12-29 000:00',
            'ylabel': 'donation rate',
            'index': 'hour'
}
plot_rate_by_time(don, imp, {'Top Mob': '.*_tp.* C14_en5C_dec_mob_FR'}, **config )
