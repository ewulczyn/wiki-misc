# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import pandas as pd
pd.options.display.mpl_style = 'default'

from banner_count import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
start = '2014-11-30 00:00'
stop = '2014-12-14 23:59'

don = get_donations_by_banner_count(start, stop)
# Out:
# /Users/ellerywulczyn/wmf/util/db_utils.py:27: Warning:
#
# Truncated incorrect INTEGER value: '1�'
#
# /Users/ellerywulczyn/wmf/util/db_utils.py:27: Warning:
#
# Truncated incorrect INTEGER value: '2�'
#
# /Users/ellerywulczyn/wmf/util/db_utils.py:27: Warning:
#
# Truncated incorrect INTEGER value: '3�'

# %%
start = '2014-11-30'
stop = '2014-12-14'

imp = get_impressions_by_banner_count(start, stop)

# %% [markdown]
# # What Impression Readers are on broken down by day

# %%
regs = {
        'Dec 13-14': '.* C14_en5C_dec_dsk_FR 2014-12-1[3-4]',
        'Dec 10-12': '.* C14_en5C_dec_dsk_FR 2014-12-1[0-2]',
        'Dec 2-9': '.* C14_en5C_dec_dsk_FR 2014-12-0[2-9]'
       }

plot_by_impressions_seen(imp, regs ,normalize = True ,max_impressions = 10, ylabel = 'percent')

# %% [markdown]
# # What Impression Readers are on broken down by banner type and day

# %% [markdown]
# ### Large

# %%
regs = {
        

        'Large Dec 13-14': '.*5C_lg.* C14_en5C_dec_dsk_FR 2014-12-1[3-4]',
        'Large Dec 10-12': '.*5C_lg.* C14_en5C_dec_dsk_FR 2014-12-1[0-2]',
        'Large Dec 2-9': '.*5C_lg.* C14_en5C_dec_dsk_FR 2014-12-0[2-9]'
       }


plot_by_impressions_seen(imp,regs, normalize = True ,max_impressions = 10)

# %% [markdown]
# Readers who see their full screen banner earlier in the campaign have seen more banners already. Makes sense: if you use the site more, you are more likely to have seen more banners from the low level campaign and to have seen your full screen banner in the first few days

# %% [markdown]
# ###Top

# %%
regs = {
        'Top Dec 7-9': '.*5C_tp.* C14_en5C_dec_dsk_FR 2014-12-0[7-9]',
        'Top Dec 4-6': '.*5C_tp.* C14_en5C_dec_dsk_FR 2014-12-0[4-6]',
        'Top Dec 2-3': '.*5C_tp.* C14_en5C_dec_dsk_FR 2014-12-0[2-3]'
       }


plot_by_impressions_seen(imp,regs, normalize = True ,max_impressions = 10, interactive = True)
# Out:
# /Users/ellerywulczyn/anaconda/lib/python2.7/site-packages/plotly/matplotlylib/renderer.py:382: UserWarning:
#
# Bummer! Plotly can currently only draw Line2D objects from matplotlib that are in 'data' coordinates!
#
# /Users/ellerywulczyn/anaconda/lib/python2.7/site-packages/plotly/matplotlylib/renderer.py:479: UserWarning:
#
# I found a path object that I don't think is part of a bar chart. Ignoring.

# %% [markdown]
# There should not be anyone who saw a top screen banner as their first impression. Still some people did. This will throw of the donation rate estimation for the top screen banner on impression one.

# %% [markdown]
# #Donation rate broken down by impression count

# %%
regs ={
'Large': '.*5C_lg.* C14_en5C_dec_dsk_FR',
'Top': '.*5C_tp.* C14_en5C_dec_dsk_FR '
}

plot_donation_rate(don, imp, regs, cum = False ,max_impressions = 20)

# %% [markdown]
# #Donation rate broken down by banner count and day

# %% [markdown]
# ###Large

# %%
regs = {
        'Large Dec 10-14': '.*5C_lg.* C14_en5C_dec_dsk_FR 2014-12-1[0-4]',
        'Large Dec 5-9': '.*5C_lg.* C14_en5C_dec_dsk_FR 2014-12-0[5-9]',
        'Large Dec 2-5': '.*5C_lg.* C14_en5C_dec_dsk_FR 2014-12-0[2-5]'
       }

plot_donation_rate(don, imp, regs, cum = False ,max_impressions = 20)

# %% [markdown]
# Hypothesis:
# If you use the site more often, you see more banners. If you use the site more often, you are more likely to donate.  Donation rate increases as a function of impressions until impression 6, because really its is dontation rate as a function of how much you use the site. After 6 it goes down die to banner fatigue.

# %% [markdown]
# ###Top

# %%
regs = {
        'Top Dec 14': '.*5C_tp.* C14_en5C_dec_dsk_FR 2014-12-14',
        'Top Dec 4-6': '.*5C_tp.* C14_en5C_dec_dsk_FR 2014-12-0[4-6]',
        'Top Dec 2-3': '.*5C_tp.* C14_en5C_dec_dsk_FR 2014-12-0[2-3]',
       }
plot_donation_rate(don, imp, regs, cum = False ,max_impressions = 10)

# %% [markdown]
# Note: Due to small sample size on the first impressions (this can only happen due to a bug or cookie clearing) you cannot trust the donation rate on impression 1.

# %% [markdown]
# #What impression our top screen donors are on

# %%
regs = {
        #'Large': '.*5C_lg.* C14_en5C_dec_dsk_FR ',
        'Top Dec 2-4': '.* C14_en5C_dec_dsk_FR 2014-12-0[2-3]',
        'Top Dec 13-14': '.* C14_en5C_dec_dsk_FR 2014-12-1[3-4]'
       }
config = {
    'normalize' : True,
    'max_impressions' : 5,
    #'interactive' : True, 
    'ylabel': 'fraction of donations'
}


plot_by_impressions_seen(don,regs,**config)

# %%
config = {
    'normalize' : True,
    'max_impressions' : 3,
    'interactive' : True, 
    'amount' : True,
    'ylabel': 'fraction of doallars'
}


plot_by_impressions_seen(don,regs,**config)
