# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import matplotlib.pyplot as plt
pd.options.display.mpl_style = 'default'
import collections 

from conversion_analysis import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
start = '2014-11-28 00:00'
stop = '2015-01-03 00:00'

don = get_clicks(start, stop, 'C14_en5C_dec_(mob|dsk|ipd)_FR')
# Out:
#     SELECT
#     DATE_FORMAT(CAST(ts as datetime), '%Y-%m-%d %H') as timestamp,
#     CONCAT_WS(' ', banner, utm_campaign) as name,
#     ct.country as country,
#     cs.payment_method as payment_method,
#     COUNT(*) as n,
#     CASE
#         WHEN contribution_id is NULL THEN 0.0
#         ELSE 1.0
#     END as donation
#     FROM drupal.contribution_tracking ct INNER JOIN drupal.contribution_source cs ON ct.id = cs.contribution_tracking_id
#     LEFT JOIN civicrm.civicrm_contribution co ON co.id = ct.contribution_id
#     WHERE ts BETWEEN 20141128000000 AND 20150103000000
#     AND utm_medium = 'sitenotice'
#     AND utm_campaign REGEXP C14_en5C_dec_(mob|dsk|ipd)_FR
#     GROUP BY timestamp, name, donation, country, payment_method

# %%
desk_regs = {
    'Large Desk': '.*5C_lg.* C14_en5C_dec_dsk_FR',
    'Top Desk': '.*5C_tp.* C14_en5C_dec_dsk_FR',
}

# %%
mob_regs = {
    'Large Mobile': '.*_lg.* C14_en5C_dec_mob_FR',
    'Top Mobile': '.*_tp.* C14_en5C_dec_mob_FR'
}

# %%
don['weekday'] = don.index.weekday
don['hour'] = don.index.hour

# %%
don_us = don[don['country']=='US']
don_gb = don[don['country']=='GB']
don_ca = don[don['country']=='CA']
don_au = don[don['country']=='AU']

# %% [markdown]
# Lets First Look at trends across the course of the cmapaign

# %%
regs = collections.OrderedDict()

regs['Large Desk'] = '.*5C_lg.* C14_en5C_dec_dsk_FR'
regs['Large Mobile'] = '.*_lg.* C14_en5C_dec_mob_FR'

plot_conversion_rate(don_us,desk_regs, stop = '2014-12-31 00:00', hours = 24, title = 'US' )

# %% [markdown]
# We see rates increase after limiting to 5 impressions per client on the 17th

# %%
plot_conversion_rate(don_us,mob_regs, start = '2014-12-09 00:00', stop = '2014-12-31 00:00', hours = 24, title = 'US' )

# %% [markdown]
# There appears to be less timporal trends on the mobile conversion rates. Lets Look at temporal trends in detail:

# %%
plot_conversion_rate(don_us,desk_regs, stop = '2014-12-31 00:00', hours = 24, title = 'US', index = 'weekday' )

# %%
plot_conversion_rate(don_au,desk_regs, stop = '2014-12-31 00:00', hours = 24, title = 'AU', index = 'weekday', methods = ['cc', 'paypal'] )

# %% [markdown]
# How about mobile?

# %%
plot_conversion_rate(don_us,mob_regs, stop = '2014-12-31 00:00', hours = 24, title = 'US', index = 'weekday' )

# %%
plot_conversion_rate(don_au,mob_regs, stop = '2014-12-31 00:00', hours = 24, title = 'AU', index = 'weekday', methods = ['cc', 'paypal'] )

# %%
plot_conversion_rate(don_gb,mob_regs, stop = '2014-12-31 00:00', hours = 24, title = 'GB', index = 'weekday', methods = ['cc', 'paypal'] )

# %% [markdown]
# Lets look at hourly trends:

# %%
plot_conversion_rate(don_us,desk_regs, stop = '2014-12-31 00:00', hours = 24, title = 'US', index = 'hour' )

# %%
plot_conversion_rate(don_au,desk_regs, stop = '2014-12-31 00:00', hours = 24, title = 'AU', index = 'hour',methods = ['cc', 'paypal'] )

# %%
plot_conversion_rate(don_gb,desk_regs, stop = '2014-12-31 00:00', hours = 24, title = 'GB', index = 'hour',methods = ['cc', 'paypal'] )

# %% [markdown]
# Now for mobile:

# %%
plot_conversion_rate(don_us,mob_regs, stop = '2014-12-31 00:00', hours = 24, title = 'US', index = 'hour')

# %%
plot_conversion_rate(don_au,mob_regs, stop = '2014-12-31 00:00', hours = 24, title = 'AU', index = 'hour',methods = ['cc', 'paypal'] )

# %%
plot_conversion_rate(don_gb,mob_regs, stop = '2014-12-31 00:00', hours = 24, title = 'GB', index = 'hour',methods = ['cc', 'paypal'] )
