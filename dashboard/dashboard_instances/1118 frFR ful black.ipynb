# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import pandas as pd
pd.options.display.mpl_style = 'default'

import inspect, os
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
os.sys.path.insert(0,parentdir) 
from src.dashboard_helpers import Test, custom_amount_stats
from src.data_retrieval import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
a ='B14_1117_frFR_dsk_ful_bg_blk' 
b = 'B14_1117_frFR_dsk_ful_bg_wht'

# %%
t_lutetium = Test(a, b, start = '2014-11-18 09:00:00', stop ='2014-11-19 03:00:00')

# %% [markdown]
# This test object loaded banner impression data from the pgehres tables on lutetium

# %%
t_hive = Test(a, b, hive = True, start = '2014-11-18 09:00:00', stop ='2014-11-19 03:00:00')

# %% [markdown]
# This test object loaded impression data from my table in hive

# %%
t_lutetium.ecom()
# Out:
#                               donations  impressions    dons/i   amount  \
# B14_1117_frFR_dsk_ful_bg_blk        801       600800  0.001333  8539.08
# B14_1117_frFR_dsk_ful_bg_wht        659       576800  0.001143  7745.66
#
#                               amount/i  clicks  clicks/i  dons/clicks  \
# B14_1117_frFR_dsk_ful_bg_blk  0.014213    1767  0.002941     0.453311
# B14_1117_frFR_dsk_ful_bg_wht  0.013429    1542  0.002673     0.427367
#
#                               amount_ro  amount_ro/i     max  median  \
# B14_1117_frFR_dsk_ful_bg_blk    7552.33     0.012570  125.07    6.25
# B14_1117_frFR_dsk_ful_bg_wht    6620.05     0.011477  250.13    6.25
#
#                                     avg     avg_ro
# B14_1117_frFR_dsk_ful_bg_blk  10.660524   9.596353
# B14_1117_frFR_dsk_ful_bg_wht  11.753657  10.153451

# %%
t_hive.ecom()
# Out:
#                               donations  traffic  impressions    dons/i  \
# B14_1117_frFR_dsk_ful_bg_blk        801   598419       412931  0.001940
# B14_1117_frFR_dsk_ful_bg_wht        659   593426       412643  0.001597
#
#                                amount  amount/i  clicks  clicks/i  \
# B14_1117_frFR_dsk_ful_bg_blk  8539.08  0.020679    1767  0.004279
# B14_1117_frFR_dsk_ful_bg_wht  7745.66  0.018771    1542  0.003737
#
#                               dons/clicks  amount_ro  amount_ro/i     max  \
# B14_1117_frFR_dsk_ful_bg_blk     0.453311    7552.33     0.018290  125.07
# B14_1117_frFR_dsk_ful_bg_wht     0.427367    6620.05     0.016043  250.13
#
#                               median        avg     avg_ro
# B14_1117_frFR_dsk_ful_bg_blk    6.25  10.660524   9.596353
# B14_1117_frFR_dsk_ful_bg_wht    6.25  11.753657  10.153451

# %%
t_hive.get_traffic_stats(a, b)
# Out:
# result                                       hide                       \
# reason                        alterImpressionData         close
# spider                                      False  True   False  True
# B14_1117_frFR_dsk_ful_bg_blk               121872     25  50994    NaN
# B14_1117_frFR_dsk_ful_bg_wht               121988     26  48383      1
#
# result                                  show
# reason                        donate      na
# spider                         False   False  True
# B14_1117_frFR_dsk_ful_bg_blk    9565  412931   3032
# B14_1117_frFR_dsk_ful_bg_wht    9478  412643    907

# %%
t_hive.plot_impressions(smooth = 1)

# %% [markdown]
# The fact that impressions dip, is totally expected since the banners were all fullscreen banners set to show up once per client

# %%
t_lutetium.plot_impressions(smooth = 10)

# %% [markdown]
# Since hive data is unsampled, it looks much cleaner. There is no notivable dip over time.

# %%
 t_hive.plot_show_hide(a, minutes = 30)

# %% [markdown]
# Here I've plotted the breakdown of result and reason fields over time. Notice how the number of hidden banners with reason=seen-fullscreen grows over time.

# %%
t_hive.rate_stats( a, b,  conf = 90, test = 'donations/impressions', plot = True)
# Out:
#                               P(Winner)      Winners Lift  \
# B14_1117_frFR_dsk_ful_bg_blk    0.99994    (0.00%, 0.00%)
# B14_1117_frFR_dsk_ful_bg_wht    0.00006  (11.42%, 32.53%)
#
#                                                 CI
# B14_1117_frFR_dsk_ful_bg_blk  (0.001831, 0.002057)
# B14_1117_frFR_dsk_ful_bg_wht  (0.001498, 0.001703)

# %%
t_lutetium.rate_stats( a, b,  conf = 90, test = 'donations/impressions', plot = True)
# Out:
#                               P(Winner)     Winners Lift                    CI
# B14_1117_frFR_dsk_ful_bg_blk    0.99824   (0.00%, 0.00%)  (0.001259, 0.001413)
# B14_1117_frFR_dsk_ful_bg_wht    0.00176  (7.06%, 27.18%)  (0.001072, 0.001218)
