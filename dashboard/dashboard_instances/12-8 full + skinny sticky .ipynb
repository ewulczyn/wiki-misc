# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import pandas as pd
pd.options.display.mpl_style = 'default'

import inspect, os
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
os.sys.path.insert(0,parentdir) 
from src.dashboard_helpers import Test, custom_amount_stats
from src.data_retrieval import *

# %%
a = 'B14_120816_5C_lg_nst'
b = 'B14_120816_5C_lg_stk'
c = 'B14_120723_5C_tp_tw1'
d = 'B14_120723_5C_tp_tw2'

start = '2014-12-8 16:41'
stop = '2014-12-8 18:45'
 



t = Test(a, b,c, d, start = start, stop = stop)

# %%
t_hive = Test(a, b,c,d, hive = True, start = start, stop = stop)

# %%
t.ecom()
# Out:
#                       donations  impressions    dons/i    amount  amount/i  \
# B14_120723_5C_tp_tw1       2056      2801000  0.000734  27042.66  0.009655
# B14_120723_5C_tp_tw2       2023      2796300  0.000723  23628.67  0.008450
# B14_120816_5C_lg_nst       2759       773500  0.003567  31747.93  0.041045
# B14_120816_5C_lg_stk       3098       687100  0.004509  33680.17  0.049018
#
#                       clicks  clicks/i  dons/clicks  amount_ro  amount_ro/i  \
# B14_120723_5C_tp_tw1    3704  0.001322     0.555076   24817.64     0.008860
# B14_120723_5C_tp_tw2    3651  0.001306     0.554095   21183.87     0.007576
# B14_120816_5C_lg_nst    4829  0.006243     0.571340   27692.67     0.035802
# B14_120816_5C_lg_stk    5307  0.007724     0.583757   30172.29     0.043913
#
#                           max  median        avg     avg_ro
# B14_120723_5C_tp_tw1  1000.00       5  13.153045  12.088475
# B14_120723_5C_tp_tw2   180.00       5  11.680015  10.602538
# B14_120816_5C_lg_nst   155.92       5  11.507042  10.188620
# B14_120816_5C_lg_stk   200.00       5  10.871585   9.850568

# %%
t_hive.ecom()
# Out:
#                       donations  traffic  impressions    dons/i    amount  \
# B14_120723_5C_tp_tw1       2056  3724908      2786746  0.000738  27042.66
# B14_120723_5C_tp_tw2       2023  3730366      2783933  0.000727  23628.67
# B14_120816_5C_lg_nst       2759   891236       774718  0.003561  31747.93
# B14_120816_5C_lg_stk       3098   805419       690313  0.004488  33680.17
#
#                       amount/i  clicks  clicks/i  dons/clicks  amount_ro  \
# B14_120723_5C_tp_tw1  0.009704    3704  0.001329     0.555076   24817.64
# B14_120723_5C_tp_tw2  0.008488    3651  0.001311     0.554095   21183.87
# B14_120816_5C_lg_nst  0.040980    4829  0.006233     0.571340   27692.67
# B14_120816_5C_lg_stk  0.048790    5307  0.007688     0.583757   30172.29
#
#                       amount_ro/i      max  median        avg     avg_ro
# B14_120723_5C_tp_tw1     0.008906  1000.00       5  13.153045  12.088475
# B14_120723_5C_tp_tw2     0.007609   180.00       5  11.680015  10.602538
# B14_120816_5C_lg_nst     0.035745   155.92       5  11.507042  10.188620
# B14_120816_5C_lg_stk     0.043708   200.00       5  10.871585   9.850568

# %%
t_hive.get_traffic_stats(a, b, c, d)
# Out:
# result                  hide                                                  \
# reason                 close         cookie  cookies-disabled         donate
# spider                 False  True    False             False  True    False
# B14_120723_5C_tp_tw1  902667     17     NaN               NaN    NaN   32804
# B14_120723_5C_tp_tw2  912709      8     NaN               NaN    NaN   30850
# B14_120816_5C_lg_nst   67917    NaN      15              7456      4   26709
# B14_120816_5C_lg_stk   65250    NaN       1              7531      3   26007
#
# result                                                  na     show
# reason                       seen-fullscreen            na       na
# spider                True             False  True   False    False  True
# B14_120723_5C_tp_tw1      1              NaN    NaN      2  2786746   2671
# B14_120723_5C_tp_tw2    NaN              NaN    NaN      8  2783933   2858
# B14_120816_5C_lg_nst    NaN            10894     79      2   774718   3442
# B14_120816_5C_lg_stk    NaN            10950     89      5   690313   5270

# %%
t.plot_impressions( smooth = 1)

# %%
t_hive.plot_impressions()

# %%
t_hive.plot_show_hide(a, minutes = 5)

# %%
t_hive.plot_utm_key( max_key=5)

# %%
t.rate_stats(conf = 99)
# Out:
#                              P(Winner)     Winners Lift                    CI
# B14_120322_5C_lg_dsn_logo_n    0.55684   (0.00%, 0.00%)  (0.005792, 0.006491)
# B14_120322_5C_lg_dsn_logo_y    0.44316  (-7.26%, 9.03%)  (0.005762, 0.006467)

# %%
t_hive.rate_stats( conf = 99)
# Out:
#                              P(Winner)     Winners Lift                    CI
# B14_120322_5C_lg_dsn_logo_n    0.59642   (0.00%, 0.00%)  (0.005799, 0.006493)
# B14_120322_5C_lg_dsn_logo_y    0.40358  (-7.01%, 9.18%)  (0.005750, 0.006445)
