# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import pandas as pd
pd.options.display.mpl_style = 'default'

import inspect, os
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
os.sys.path.insert(0,parentdir) 
from src.dashboard_helpers import Test, custom_amount_stats
from src.data_retrieval import *

# %%
full = 'B14_1130_fl_fl_enUS'
top = 'B14_1130_fl_tp_enUS'
t = Test(top, full)

# %%
t_hive = Test(top, full, hive = True, start = '2014-11-30')

# %%
t.ecom()
# Out:
#                      donations  impressions    dons/i    amount  amount/i  \
# B14_1130_fl_fl_enUS       3668       367700  0.009976  47171.45  0.128288
# B14_1130_fl_tp_enUS        873       883000  0.000989  12253.76  0.013877
#
#                      clicks  clicks/i  dons/clicks  amount_ro  amount_ro/i  \
# B14_1130_fl_fl_enUS    5185  0.014101     0.707425   38331.45     0.104247
# B14_1130_fl_tp_enUS    1226  0.001388     0.712072   10553.76     0.011952
#
#                      max  median        avg     avg_ro
# B14_1130_fl_fl_enUS  500       5  12.860264  10.674311
# B14_1130_fl_tp_enUS  100       5  14.036380  12.329159

# %%
t_hive.ecom()
# Out:
#                      donations  traffic  impressions    dons/i    amount  \
# B14_1130_fl_fl_enUS       3668   370055       249434  0.014705  47171.45
# B14_1130_fl_tp_enUS        873   882789       183749  0.004751  12253.76
#
#                      amount/i  clicks  clicks/i  dons/clicks  amount_ro  \
# B14_1130_fl_fl_enUS  0.189114    5185  0.020787     0.707425   38331.45
# B14_1130_fl_tp_enUS  0.066687    1226  0.006672     0.712072   10553.76
#
#                      amount_ro/i  max  median        avg     avg_ro
# B14_1130_fl_fl_enUS     0.153674  500       5  12.860264  10.674311
# B14_1130_fl_tp_enUS     0.057436  100       5  14.036380  12.329159

# %% [markdown]
# Hmm, either the patch has not been deployed or the impression numbers from pgeheres are still wrong. Also, why where the banners served differently? Could it be a bug with the banner?

# %%
t_hive.get_traffic_stats(top, full)
# Out:
# result                              hide                        \
# reason               alterImpressionData  close         donate
# spider                             False  False  True    False
# B14_1130_fl_fl_enUS                  NaN  30299    NaN    6962
# B14_1130_fl_tp_enUS                   10  49800      4    8025
#
# result                                                                    na  \
# reason               seen-fullscreen         waitdate         waiterr     na
# spider                         False  True      False  True     False  False
# B14_1130_fl_fl_enUS            82615     88       NaN    NaN      NaN    NaN
# B14_1130_fl_tp_enUS              NaN    NaN    637243    297     2202      1
#
# result                          show
# reason               waitdat      na
# spider                 False   False  True
# B14_1130_fl_fl_enUS      NaN  249402    507
# B14_1130_fl_tp_enUS        2  183654    900

# %%
t.plot_impressions(top, full, smooth = 1, stop = '2014-11-30 17:35')

# %%
t_hive.plot_impressions(top, full, smooth = 1, stop = '2014-11-30 17:35')

# %%
t_hive.plot_show_hide(top, stop = '2014-11-30 17:35')

# %%
t_hive.plot_show_hide(full, stop = '2014-11-30 17:35')

# %% [markdown]
# Again there needs to the a result and reason url query paramter in RecordImpresion!! Something is wrong.

# %%
t.plot_utm_key(top, full, max_key=5)
