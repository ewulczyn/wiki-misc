# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import pandas as pd
pd.options.display.mpl_style = 'default'

import inspect, os
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
os.sys.path.insert(0,parentdir) 
from src.dashboard_helpers import Test, custom_amount_stats
from src.data_retrieval import *

# %%
full = 'B14_113022_5c_fl_enUS'
top = 'B14_113022_5c_hf_enUS'
t = Test(top, full, start ='2014-11-30-22:00', stop = '2014-11-30 23:59')

# %%
t_hive = Test(top, full, hive = True, start ='2014-11-30-22:00', stop = '2014-11-30 23:59')

# %%
t.ecom()
# Out:
#                        donations  impressions    dons/i    amount  amount/i  \
# B14_113022_5c_fl_enUS       5355      1236900  0.004329  66038.13  0.053390
# B14_113022_5c_hf_enUS       3062      1268000  0.002415  41009.34  0.032342
#
#                        clicks  clicks/i  dons/clicks  amount_ro  amount_ro/i  \
# B14_113022_5c_fl_enUS    7960  0.006435     0.672739   54048.13     0.043696
# B14_113022_5c_hf_enUS    4645  0.003663     0.659203   33709.34     0.026585
#
#                         max  median        avg     avg_ro
# B14_113022_5c_fl_enUS  1000       5  12.332050  10.292921
# B14_113022_5c_hf_enUS   500       5  13.392992  11.221485

# %%
t_hive.ecom()
# Out:
#                        donations  traffic  impressions    dons/i    amount  \
# B14_113022_5c_fl_enUS       5355  1253328       469867  0.011397  66038.13
# B14_113022_5c_hf_enUS       3062  1288184       491154  0.006234  41009.34
#
#                        amount/i  clicks  clicks/i  dons/clicks  amount_ro  \
# B14_113022_5c_fl_enUS  0.140546    7960  0.016941     0.672739   54048.13
# B14_113022_5c_hf_enUS  0.083496    4645  0.009457     0.659203   33709.34
#
#                        amount_ro/i   max  median        avg     avg_ro
# B14_113022_5c_fl_enUS     0.115029  1000       5  12.332050  10.292921
# B14_113022_5c_hf_enUS     0.068633   500       5  13.392992  11.221485

# %%
t_hive.get_traffic_stats(top, full)
# Out:
# result                  hide                                                  \
# reason                 close         cookie  cookies-disabled         donate
# spider                 False  True    False             False  True    False
# B14_113022_5c_fl_enUS  62464    NaN     NaN               NaN    NaN   14530
# B14_113022_5c_hf_enUS  62777      1       9              1759      2   15059
#
# result                                            na    show
# reason                 seen-fullscreen            na      na
# spider                           False  True   False   False  True
# B14_113022_5c_fl_enUS           704819    602    NaN  469867   1046
# B14_113022_5c_hf_enUS           715223    610      1  491154   1589

# %%
t.plot_impressions(top, full, smooth = 1, start ='2014-11-30-22:00', stop = '2014-11-30 23:59')

# %%
t_hive.plot_impressions(top, full, smooth = 1)

# %%
t_hive.plot_show_hide(top, stop = '2014-12-1 01:00')

# %%
t_hive.plot_show_hide(full, stop = '2014-12-1 01:00')

# %% [markdown]
# Again there needs to the a result and reason url query paramter in RecordImpresion!! Something is wrong.
