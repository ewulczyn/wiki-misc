# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import pandas as pd
pd.options.display.mpl_style = 'default'

import inspect, os
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
os.sys.path.insert(0,parentdir) 
from src.dashboard_helpers import Test, custom_amount_stats
from src.data_retrieval import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
a = 'B14_120223_5C_lg_by'
b = 'B14_120223_5C_lg_hl'
c = 'B14_120223_5C_lg_ii'
d = 'B14_120223_5C_lg_lh'



t = Test(a, b, c, d, start = '2014-12-02 19:07', stop = '2014-12-03 01:05')

# %%
t_hive = Test(a, b, c, d, hive = True, start = '2014-12-02 19:07', stop = '2014-12-03 01:05')

# %%
t.ecom()
# Out:
#                      donations  impressions    dons/i    amount  amount/i  \
# B14_120223_5C_lg_by       3781       478100  0.007908  42029.00  0.087908
# B14_120223_5C_lg_hl       3697       484900  0.007624  39527.12  0.081516
# B14_120223_5C_lg_ii       3644       476600  0.007646  41131.57  0.086302
# B14_120223_5C_lg_lh       3189       465000  0.006858  35454.03  0.076245
#
#                      clicks  clicks/i  dons/clicks  amount_ro  amount_ro/i  \
# B14_120223_5C_lg_by    5787  0.012104     0.653361   35744.55     0.074764
# B14_120223_5C_lg_hl    5760  0.011879     0.641840   33387.14     0.068854
# B14_120223_5C_lg_ii    5753  0.012071     0.633409   34728.05     0.072866
# B14_120223_5C_lg_lh    5047  0.010854     0.631861   30437.53     0.065457
#
#                       max  median        avg    avg_ro
# B14_120223_5C_lg_by   350       5  11.115842  9.603587
# B14_120223_5C_lg_hl  1000       5  10.691674  9.162223
# B14_120223_5C_lg_ii   500       5  11.287478  9.689746
# B14_120223_5C_lg_lh   500       5  11.117601  9.687311

# %%
t_hive.ecom()
# Out:
#                      donations  traffic  impressions    dons/i    amount  \
# B14_120223_5C_lg_by       3781   631526       473801  0.007980  42029.00
# B14_120223_5C_lg_hl       3697   629944       474940  0.007784  39527.12
# B14_120223_5C_lg_ii       3644   629270       474878  0.007674  41131.57
# B14_120223_5C_lg_lh       3189   634616       475860  0.006702  35454.03
#
#                      amount/i  clicks  clicks/i  dons/clicks  amount_ro  \
# B14_120223_5C_lg_by  0.088706    5787  0.012214     0.653361   35744.55
# B14_120223_5C_lg_hl  0.083226    5760  0.012128     0.641840   33387.14
# B14_120223_5C_lg_ii  0.086615    5753  0.012115     0.633409   34728.05
# B14_120223_5C_lg_lh  0.074505    5047  0.010606     0.631861   30437.53
#
#                      amount_ro/i   max  median        avg    avg_ro
# B14_120223_5C_lg_by     0.075442   350       5  11.115842  9.603587
# B14_120223_5C_lg_hl     0.070298  1000       5  10.691674  9.162223
# B14_120223_5C_lg_ii     0.073130   500       5  11.287478  9.689746
# B14_120223_5C_lg_lh     0.063963   500       5  11.117601  9.687311

# %%
t_hive.get_traffic_stats(a, b, c, d)
# Out:
# result                 hide                                                  \
# reason                close         cookie  cookies-disabled         donate
# spider                False  True    False             False  True    False
# B14_120223_5C_lg_by  103092    NaN      12              3410      4   11602
# B14_120223_5C_lg_hl  100612    NaN     NaN              3440      5   11125
# B14_120223_5C_lg_ii   99862    NaN     NaN              3429      5   10969
# B14_120223_5C_lg_lh  102406      1      16              3454      1   11517
#
# result                                          na    show
# reason               seen-fullscreen            na      na
# spider                         False  True   False   False  True
# B14_120223_5C_lg_by            38201     42      1  473801   1361
# B14_120223_5C_lg_hl            38460     39    NaN  474940   1323
# B14_120223_5C_lg_ii            38683     44      1  474878   1399
# B14_120223_5C_lg_lh            38206     31      1  475860   3123

# %%
t.plot_impressions( smooth = 1, stop = '2014-12-03 01:05')

# %%
t_hive.plot_impressions(a, b, c, d, smooth = 1)

# %%
t_hive.plot_show_hide(a, minutes = 5)

# %%
t_hive.plot_utm_key( max_key=5)

# %%
t.rate_stats(conf = 99)
# Out:
#                      P(Winner)      Winners Lift                    CI
# B14_120223_5C_lg_by    0.88856    (0.00%, 0.00%)  (0.007588, 0.008242)
# B14_120223_5C_lg_ii    0.06452   (-2.47%, 9.78%)  (0.007325, 0.007975)
# B14_120223_5C_lg_hl    0.04692  (-2.26%, 10.11%)  (0.007308, 0.007952)
# B14_120223_5C_lg_lh        NaN   (8.39%, 22.59%)  (0.006553, 0.007174)

# %%
t_hive.rate_stats(a, b, conf = 99)
# Out:
#                      P(Winner)     Winners Lift                    CI
# B14_120223_5C_lg_by    0.85644   (0.00%, 0.00%)  (0.007651, 0.008317)
# B14_120223_5C_lg_hl    0.14356  (-3.44%, 8.83%)  (0.007460, 0.008120)
