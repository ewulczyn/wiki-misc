# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import pandas as pd
pd.options.display.mpl_style = 'default'

import inspect, os
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
os.sys.path.insert(0,parentdir) 
from src.dashboard_helpers import Test, custom_amount_stats
from src.data_retrieval import *

# %%
a ='B14_1112_frFR_dsk_ful_dsn_cbold' 
b = 'B14_1112_frFR_dsk_ful_dsn_ccntl'

# %%
t_lutetium = Test(a, b, start = '2014-11-11 09:00:00', stop ='2014-11-13 17:00:00')

# %% [markdown]
# This test object loaded banner impression data from the pgehres tables on lutetium

# %%
t_hive = Test(a, b, hive = True, start = '2014-11-11 09:00:00', stop ='2014-11-13 17:00:00')

# %% [markdown]
# This test object loaded impression data from my table in hive

# %%
t_lutetium.ecom()
# Out:
#                                  donations  impressions    dons/i    amount  \
# B14_1112_frFR_dsk_ful_dsn_cbold       1881      1130300  0.001664  20380.03
# B14_1112_frFR_dsk_ful_dsn_ccntl       1656      1132800  0.001462  17803.31
#
#                                  amount/i  clicks  clicks/i  dons/clicks  \
# B14_1112_frFR_dsk_ful_dsn_cbold  0.018031    4152  0.003673     0.453035
# B14_1112_frFR_dsk_ful_dsn_ccntl  0.015716    3799  0.003354     0.435904
#
#                                  amount_ro  amount_ro/i     max  median  \
# B14_1112_frFR_dsk_ful_dsn_cbold   17143.60     0.015167  249.27    6.23
# B14_1112_frFR_dsk_ful_dsn_ccntl   15003.52     0.013245  186.49    6.23
#
#                                        avg    avg_ro
# B14_1112_frFR_dsk_ful_dsn_cbold  10.834678  9.327312
# B14_1112_frFR_dsk_ful_dsn_ccntl  10.750791  9.250012

# %%
t_hive.ecom()
# Out:
#                                  donations  traffic  impressions    dons/i  \
# B14_1112_frFR_dsk_ful_dsn_cbold       1881  1125657       844793  0.002227
# B14_1112_frFR_dsk_ful_dsn_ccntl       1656  1131055       845877  0.001958
#
#                                    amount  amount/i  clicks  clicks/i  \
# B14_1112_frFR_dsk_ful_dsn_cbold  20380.03  0.024124    4152  0.004915
# B14_1112_frFR_dsk_ful_dsn_ccntl  17803.31  0.021047    3799  0.004491
#
#                                  dons/clicks  amount_ro  amount_ro/i     max  \
# B14_1112_frFR_dsk_ful_dsn_cbold     0.453035   17143.60     0.020293  249.27
# B14_1112_frFR_dsk_ful_dsn_ccntl     0.435904   15003.52     0.017737  186.49
#
#                                  median        avg    avg_ro
# B14_1112_frFR_dsk_ful_dsn_cbold    6.23  10.834678  9.327312
# B14_1112_frFR_dsk_ful_dsn_ccntl    6.23  10.750791  9.250012

# %%
t_hive.get_traffic_stats(a, b)
# Out:
# result                                          hide                        \
# reason                           alterImpressionData          close
# spider                                         False  True    False  True
# B14_1112_frFR_dsk_ful_dsn_cbold               156676     39  111137      5
# B14_1112_frFR_dsk_ful_dsn_ccntl               157796     29  112925    NaN
#
# result                                     show
# reason                           donate      na
# spider                            False   False  True
# B14_1112_frFR_dsk_ful_dsn_cbold   11653  844793   1354
# B14_1112_frFR_dsk_ful_dsn_ccntl   10316  845877   4112

# %%
t_hive.plot_impressions(smooth = 1)

# %% [markdown]
# The fact that impressions dip, is totally expected since the banners were all fullscreen banners set to show up once per client

# %%
t_lutetium.plot_impressions(smooth = 10)

# %% [markdown]
# Since hive data is unsampled, it looks much cleaner. There is no notivable dip over time.

# %%
 t_hive.plot_show_hide(a, minutes = 30)

# %% [markdown]
# Here I've plotted the breakdown of result and reason fields over time. Notice how the number of hidden banners with reason=seen-fullscreen grows over time.

# %%
t_hive.rate_stats( a, b,  conf = 90, test = 'donations/impressions', plot = True)
# Out:
#                                  P(Winner)     Winners Lift  \
# B14_1112_frFR_dsk_ful_dsn_cbold    0.99992   (0.00%, 0.00%)
# B14_1112_frFR_dsk_ful_dsn_ccntl    0.00008  (7.63%, 20.22%)
#
#                                                    CI
# B14_1112_frFR_dsk_ful_dsn_cbold  (0.002145, 0.002313)
# B14_1112_frFR_dsk_ful_dsn_ccntl  (0.001880, 0.002039)

# %%
t_lutetium.rate_stats( a, b,  conf = 90, test = 'donations/impressions', plot = True)
# Out:
#                                  P(Winner)     Winners Lift  \
# B14_1112_frFR_dsk_ful_dsn_cbold    0.99992   (0.00%, 0.00%)
# B14_1112_frFR_dsk_ful_dsn_ccntl    0.00008  (7.74%, 20.35%)
#
#                                                    CI
# B14_1112_frFR_dsk_ful_dsn_cbold  (0.001603, 0.001728)
# B14_1112_frFR_dsk_ful_dsn_ccntl  (0.001404, 0.001523)
