# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import pandas as pd
pd.options.display.mpl_style = 'default'

import inspect, os
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
os.sys.path.insert(0,parentdir) 
from src.dashboard_helpers import Test, custom_amount_stats
from src.data_retrieval import *

# %%
a = 'B14_120316_5C_lg_tx_ind'
b = 'B14_120316_5C_lg_tx_onl'
start = '2014-12-3 16:23:00'
stop = '2014-12-3 17:26:00'
 



t = Test(a, b, start = start, stop = stop)

# %%
t_hive = Test(a, b, hive = True, start = start, stop = stop)

# %%
t.ecom()
# Out:
#                          donations  impressions    dons/i    amount  amount/i  \
# B14_120316_5C_lg_tx_ind       3479       539500  0.006449  36778.08  0.068171
# B14_120316_5C_lg_tx_onl       2611       417100  0.006260  27048.38  0.064849
#
#                          clicks  clicks/i  dons/clicks  amount_ro  \
# B14_120316_5C_lg_tx_ind    5535  0.010259     0.628546   33554.56
# B14_120316_5C_lg_tx_onl    4133  0.009909     0.631744   21142.90
#
#                          amount_ro/i     max  median        avg    avg_ro
# B14_120316_5C_lg_tx_ind     0.062196  156.96       5  10.571452  9.734424
# B14_120316_5C_lg_tx_onl     0.050690  100.00       5  10.359395  8.403378

# %%
t_hive.ecom()
# Out:
#                          donations  traffic  impressions    dons/i    amount  \
# B14_120316_5C_lg_tx_ind       3479   783708       637472  0.005457  36778.08
# B14_120316_5C_lg_tx_onl       2611   607525       494264  0.005283  27048.38
#
#                          amount/i  clicks  clicks/i  dons/clicks  amount_ro  \
# B14_120316_5C_lg_tx_ind  0.057694    5535  0.008683     0.628546   33554.56
# B14_120316_5C_lg_tx_onl  0.054725    4133  0.008362     0.631744   21142.90
#
#                          amount_ro/i     max  median        avg    avg_ro
# B14_120316_5C_lg_tx_ind     0.052637  156.96       5  10.571452  9.734424
# B14_120316_5C_lg_tx_onl     0.042777  100.00       5  10.359395  8.403378

# %%
t_hive.get_traffic_stats(a, b)
# Out:
# result                    hide                                           \
# reason                   close  cookie  cookies-disabled         donate
# spider                   False   False             False  True    False
# B14_120316_5C_lg_tx_ind  99606       3              4947      2   13580
# B14_120316_5C_lg_tx_onl  77348     NaN              3915      1   10946
#
# result                                              na    show
# reason                   seen-fullscreen            na      na
# spider                             False  True   False   False  True
# B14_120316_5C_lg_tx_ind            25387     43      3  637472   2665
# B14_120316_5C_lg_tx_onl            19733     25      1  494264   1292

# %%
t.plot_impressions( smooth = 1)

# %%
t_hive.plot_impressions()

# %%
t_hive.plot_show_hide(a, minutes = 5)

# %%
t_hive.plot_utm_key( max_key=5)

# %%
t.rate_stats(conf = 99)
# Out:
#                          P(Winner)      Winners Lift                    CI
# B14_120316_5C_lg_tx_ind    0.87312    (0.00%, 0.00%)  (0.006172, 0.006732)
# B14_120316_5C_lg_tx_onl    0.12688  (-3.62%, 10.13%)  (0.005951, 0.006582)

# %%
t_hive.rate_stats( conf = 99)
# Out:
#                          P(Winner)      Winners Lift                    CI
# B14_120316_5C_lg_tx_ind    0.89572    (0.00%, 0.00%)  (0.005224, 0.005695)
# B14_120316_5C_lg_tx_onl    0.10428  (-3.25%, 10.37%)  (0.005025, 0.005553)
