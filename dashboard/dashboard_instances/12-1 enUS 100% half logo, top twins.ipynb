# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import pandas as pd
pd.options.display.mpl_style = 'default'

import inspect, os
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
os.sys.path.insert(0,parentdir) 
from src.dashboard_helpers import Test, custom_amount_stats
from src.data_retrieval import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
a = 'B14_120204_5C_lg_n'
b = 'B14_120204_5C_lg_y'
c = 'B14_120204_5C_tp_tn1'
d = 'B14_120204_5C_tp_tn2'
t = Test(a, b, c, d, start = '2014-12-02 4:07', stop = '2014-12-02 5:11')

# %%
t_hive = Test(a, b, c, d, hive = True, start = '2014-12-02 4:07', stop = '2014-12-02 5:11')

# %%
t.ecom()
# Out:
#                       donations  impressions    dons/i    amount  amount/i  \
# B14_120204_5C_lg_n         2213       442900  0.004997  25869.20  0.058409
# B14_120204_5C_lg_y         2498       435500  0.005736  29420.99  0.067557
# B14_120204_5C_tp_tn1        781       678300  0.001151   9440.57  0.013918
# B14_120204_5C_tp_tn2        813       710800  0.001144  10261.00  0.014436
#
#                       clicks  clicks/i  dons/clicks  amount_ro  amount_ro/i  \
# B14_120204_5C_lg_n      3382  0.007636     0.654347   21809.20     0.049242
# B14_120204_5C_lg_y      3834  0.008804     0.651539   23995.99     0.055100
# B14_120204_5C_tp_tn1    1203  0.001774     0.649210    7940.57     0.011707
# B14_120204_5C_tp_tn2    1232  0.001733     0.659903    8063.00     0.011344
#
#                       max  median        avg     avg_ro
# B14_120204_5C_lg_n    200       5  11.689652  10.036447
# B14_120204_5C_lg_y    250       5  11.777818   9.814311
# B14_120204_5C_tp_tn1  200       5  12.087798  10.352764
# B14_120204_5C_tp_tn2  500       5  12.621156  10.142138

# %%
t_hive.ecom()
# Out:
#                       donations  traffic  impressions    dons/i    amount  \
# B14_120204_5C_lg_n         2213   509206       440882  0.005019  25869.20
# B14_120204_5C_lg_y         2498   504739       435132  0.005741  29420.99
# B14_120204_5C_tp_tn1        781   796755       678483  0.001151   9440.57
# B14_120204_5C_tp_tn2        813   863281       732403  0.001110  10261.00
#
#                       amount/i  clicks  clicks/i  dons/clicks  amount_ro  \
# B14_120204_5C_lg_n    0.058676    3382  0.007671     0.654347   21809.20
# B14_120204_5C_lg_y    0.067614    3834  0.008811     0.651539   23995.99
# B14_120204_5C_tp_tn1  0.013914    1203  0.001773     0.649210    7940.57
# B14_120204_5C_tp_tn2  0.014010    1232  0.001682     0.659903    8063.00
#
#                       amount_ro/i  max  median        avg     avg_ro
# B14_120204_5C_lg_n       0.049467  200       5  11.689652  10.036447
# B14_120204_5C_lg_y       0.055146  250       5  11.777818   9.814311
# B14_120204_5C_tp_tn1     0.011703  200       5  12.087798  10.352764
# B14_120204_5C_tp_tn2     0.011009  500       5  12.621156  10.142138

# %%
t_hive.get_traffic_stats(a, b, c, d)
# Out:
# result                  hide                                           \
# reason                 close         cookie  cookies-disabled  donate
# spider                 False  True    False             False   False
# B14_120204_5C_lg_n     49935    NaN     NaN              4109    7618
# B14_120204_5C_lg_y     50519      2       1              4103    7905
# B14_120204_5C_tp_tn1  111183    NaN     NaN               NaN    6461
# B14_120204_5C_tp_tn2  123582    NaN     NaN               NaN    6659
#
# result                                           na    show
# reason                seen-fullscreen            na      na
# spider                          False  True   False   False  True
# B14_120204_5C_lg_n               5514     29    NaN  440882   1119
# B14_120204_5C_lg_y               5368     27      1  435132   1681
# B14_120204_5C_tp_tn1              NaN    NaN    NaN  678483    628
# B14_120204_5C_tp_tn2                2    NaN    NaN  732403    635

# %%
t.plot_impressions(a, b, c, d, smooth = 2)

# %%
t_hive.plot_impressions(a, b, c, d, smooth = 1)

# %%
t_hive.plot_show_hide(a)

# %%
t_hive.plot_show_hide(b)

# %%
t_hive.plot_show_hide(c)

# %%
t.plot_utm_key(a, b, c, d, max_key=5)

# %%
t.rate_stats()
# Out:
#                       P(Winner)        Winners Lift                    CI
# B14_120204_5C_lg_y            1      (0.00%, 0.00%)  (0.005517, 0.005967)
# B14_120204_5C_lg_n          NaN     (8.47%, 21.52%)  (0.004795, 0.005207)
# B14_120204_5C_tp_tn1        NaN  (360.15%, 440.13%)  (0.001074, 0.001235)
# B14_120204_5C_tp_tn2        NaN  (363.66%, 442.71%)  (0.001068, 0.001225)

# %%
t_hive.rate_stats()
# Out:
#                       P(Winner)        Winners Lift                    CI
# B14_120204_5C_lg_y            1      (0.00%, 0.00%)  (0.005522, 0.005971)
# B14_120204_5C_lg_n          NaN     (8.06%, 21.06%)  (0.004815, 0.005232)
# B14_120204_5C_tp_tn1        NaN  (360.26%, 440.42%)  (0.001072, 0.001236)
# B14_120204_5C_tp_tn2        NaN  (377.44%, 459.67%)  (0.001036, 0.001189)
