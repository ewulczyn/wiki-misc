# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import pandas as pd
pd.options.display.mpl_style = 'default'

import inspect, os
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
os.sys.path.insert(0,parentdir) 
from src.dashboard_helpers import Test, custom_amount_stats
from src.data_retrieval import *

# %%
a = 'B14_120317_5C_lg_mg_ls'
b = 'B14_120317_5C_lg_mg_mr'

start = '2014-12-3 17:26:00'
stop = '2014-12-3 18:30:00'
 



t = Test(a, b, start = start, stop = stop)

# %%
t_hive = Test(a, b, hive = True, start = start, stop = stop)

# %%
t.ecom()
# Out:
#                         donations  impressions    dons/i    amount  amount/i  \
# B14_120317_5C_lg_mg_ls       3605       564600  0.006385  40544.78  0.071812
# B14_120317_5C_lg_mg_mr       3598       577800  0.006227  39889.80  0.069037
#
#                         clicks  clicks/i  dons/clicks  amount_ro  amount_ro/i  \
# B14_120317_5C_lg_mg_ls    5729  0.010147     0.629255   33362.66     0.059091
# B14_120317_5C_lg_mg_mr    5659  0.009794     0.635801   33822.48     0.058537
#
#                         max  median        avg    avg_ro
# B14_120317_5C_lg_mg_ls  500       5  11.246818  9.429808
# B14_120317_5C_lg_mg_mr  500       5  11.086659  9.546283

# %%
t_hive.ecom()
# Out:
#                         donations  traffic  impressions    dons/i    amount  \
# B14_120317_5C_lg_mg_ls       3605   705825       570564  0.006318  40544.78
# B14_120317_5C_lg_mg_mr       3598   705862       569607  0.006317  39889.80
#
#                         amount/i  clicks  clicks/i  dons/clicks  amount_ro  \
# B14_120317_5C_lg_mg_ls  0.071061    5729  0.010041     0.629255   33362.66
# B14_120317_5C_lg_mg_mr  0.070030    5659  0.009935     0.635801   33822.48
#
#                         amount_ro/i  max  median        avg    avg_ro
# B14_120317_5C_lg_mg_ls     0.058473  500       5  11.246818  9.429808
# B14_120317_5C_lg_mg_mr     0.059379  500       5  11.086659  9.546283

# %%
t_hive.get_traffic_stats(a, b)
# Out:
# result                   hide                                           \
# reason                  close  cookie  cookies-disabled         donate
# spider                  False   False             False  True    False
# B14_120317_5C_lg_mg_ls  94142       1              4404      2   13188
# B14_120317_5C_lg_mg_mr  94380       1              4269      3   13405
#
# result                                             na    show
# reason                  seen-fullscreen            na      na
# spider                            False  True   False   False  True
# B14_120317_5C_lg_mg_ls            21838     38      2  570564   1646
# B14_120317_5C_lg_mg_mr            21757     40    NaN  569607   2400

# %%
t.plot_impressions( smooth = 1)

# %%
t_hive.plot_impressions()

# %%
t_hive.plot_show_hide(a, minutes = 5)

# %%
t_hive.plot_utm_key( max_key=5)

# %%
t.rate_stats(conf = 99)
# Out:
#                         P(Winner)     Winners Lift                    CI
# B14_120317_5C_lg_mg_ls    0.85584   (0.00%, 0.00%)  (0.006117, 0.006663)
# B14_120317_5C_lg_mg_mr    0.14416  (-3.51%, 8.92%)  (0.005966, 0.006498)

# %%
t_hive.rate_stats( conf = 99)
# Out:
#                         P(Winner)     Winners Lift                    CI
# B14_120317_5C_lg_mg_ls    0.50542   (0.00%, 0.00%)  (0.006055, 0.006597)
# B14_120317_5C_lg_mg_mr    0.49458  (-5.77%, 6.37%)  (0.006047, 0.006592)
