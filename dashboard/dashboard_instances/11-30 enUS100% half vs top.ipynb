# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import pandas as pd
pd.options.display.mpl_style = 'default'

import inspect, os
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
os.sys.path.insert(0,parentdir) 
from src.dashboard_helpers import Test, custom_amount_stats
from src.data_retrieval import *

# %%
full = 'B14_120100_5c_hf_enUS'
top = 'B14_120100_5c_tp_enUS'
t = Test(top, full)

# %%
t_hive = Test(top, full, hive = True, start = '2014-11-30')

# %%
t.ecom()
# Out:
#                        donations  impressions    dons/i    amount  amount/i  \
# B14_120100_5c_hf_enUS       2915       783600  0.003720  38201.58  0.048751
# B14_120100_5c_tp_enUS       1352      2003900  0.000675  16891.10  0.008429
#
#                        clicks  clicks/i  dons/clicks  amount_ro  amount_ro/i  \
# B14_120100_5c_hf_enUS    4291  0.005476     0.679329   31801.58     0.040584
# B14_120100_5c_tp_enUS    1980  0.000988     0.682828   14891.10     0.007431
#
#                        max  median        avg     avg_ro
# B14_120100_5c_hf_enUS  500       5  13.105173  11.127215
# B14_120100_5c_tp_enUS  100       5  12.493417  11.179505

# %%
t_hive.ecom()
# Out:
#                        donations  traffic  impressions    dons/i    amount  \
# B14_120100_5c_hf_enUS       2915   803894       465791  0.006258  38201.58
# B14_120100_5c_tp_enUS       1352  2019468       385912  0.003503  16891.10
#
#                        amount/i  clicks  clicks/i  dons/clicks  amount_ro  \
# B14_120100_5c_hf_enUS  0.082014    4291  0.009212     0.679329   31801.58
# B14_120100_5c_tp_enUS  0.043769    1980  0.005131     0.682828   14891.10
#
#                        amount_ro/i  max  median        avg     avg_ro
# B14_120100_5c_hf_enUS     0.068274  500       5  13.105173  11.127215
# B14_120100_5c_tp_enUS     0.038587  100       5  12.493417  11.179505

# %%
t_hive.get_traffic_stats(top, full)
# Out:
# result                                hide                                   \
# reason                 alterImpressionData   close         cookies-disabled
# spider                               False   False  True              False
# B14_120100_5c_hf_enUS                  NaN   71483      1              2566
# B14_120100_5c_tp_enUS                   23  114792    NaN               NaN
#
# result                                                                  \
# reason                 donate  seen-fullscreen         waitdate
# spider                  False            False  True      False  True
# B14_120100_5c_hf_enUS   12382           249742    204       NaN    NaN
# B14_120100_5c_tp_enUS   14459              NaN    NaN   1498481    862
#
# result                            show
# reason                 waiterr      na
# spider                   False   False  True
# B14_120100_5c_hf_enUS      NaN  465791   1725
# B14_120100_5c_tp_enUS     3682  385912   1257

# %%
t.plot_impressions(top, full, smooth = 1, stop = '2014-12-1 01:00')

# %%
t_hive.plot_impressions(top, full, smooth = 1, stop =  '2014-12-1 01:00')

# %%
t_hive.plot_show_hide(top, stop = '2014-12-1 01:00')

# %%
t_hive.plot_show_hide(full, stop = '2014-12-1 01:00')

# %% [markdown]
# Again there needs to the a result and reason url query paramter in RecordImpresion!! Something is wrong.
