# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import pandas as pd
pd.options.display.mpl_style = 'default'

import inspect, os
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
os.sys.path.insert(0,parentdir) 
from src.dashboard_helpers import Test, custom_amount_stats
from src.data_retrieval import *

# %%
a ='B14_1028_frFR_dsk_ful_bt95' 
b = 'B14_1028_frFR_dsk_ful_btgy' 
c = 'B14_1028_frFR_dsk_ful_ctrl'
d = 'B14_1028_frFR_dsk_ful_wydg'

# %%
t_lutetium = Test(a, b, b, c, d, start = '2014-10-30 11:00:00', stop ='2014-10-31 19:00:00')

# %% [markdown]
# This test object loaded banner impression data from the pgehres tables on lutetium

# %%
t_hive = Test(a, b, c, d, hive = True, start = '2014-10-30 11:00:00', stop ='2014-10-31 19:00:00' )

# %% [markdown]
# This test object loaded impression data from my table in hive

# %%
t_lutetium.ecom()
# Out:
#                             donations  impressions    dons/i    amount  \
# B14_1028_frFR_dsk_ful_bt95       1944       364700  0.005330  19474.59
# B14_1028_frFR_dsk_ful_btgy       2173       367800  0.005908  22291.33
# B14_1028_frFR_dsk_ful_ctrl       1853       365000  0.005077  19114.89
# B14_1028_frFR_dsk_ful_wydg       2344       360100  0.006509  24173.12
#
#                             amount/i  clicks  clicks/i  dons/clicks  \
# B14_1028_frFR_dsk_ful_bt95  0.053399    3561  0.009764     0.545914
# B14_1028_frFR_dsk_ful_btgy  0.060607    4381  0.011911     0.496005
# B14_1028_frFR_dsk_ful_ctrl  0.052370    3639  0.009970     0.509206
# B14_1028_frFR_dsk_ful_wydg  0.067129    4410  0.012247     0.531519
#
#                             amount_ro  amount_ro/i     max  median        avg  \
# B14_1028_frFR_dsk_ful_bt95   17961.40     0.049250  630.49     6.3  10.017793
# B14_1028_frFR_dsk_ful_btgy   18193.09     0.049465  378.29     6.3  10.258320
# B14_1028_frFR_dsk_ful_ctrl   16340.69     0.044769  126.10     6.3  10.315645
# B14_1028_frFR_dsk_ful_wydg   22281.63     0.061876  630.49     6.3  10.312765
#
#                               avg_ro
# B14_1028_frFR_dsk_ful_bt95  9.277583
# B14_1028_frFR_dsk_ful_btgy  8.569520
# B14_1028_frFR_dsk_ful_ctrl  8.978401
# B14_1028_frFR_dsk_ful_wydg  9.550634

# %%
t_hive.ecom()
# Out:
#                             donations  traffic  impressions    dons/i  \
# B14_1028_frFR_dsk_ful_bt95       1944   374383       354716  0.005480
# B14_1028_frFR_dsk_ful_btgy       2173   365881       346295  0.006275
# B14_1028_frFR_dsk_ful_ctrl       1853   356376       345475  0.005364
# B14_1028_frFR_dsk_ful_wydg       2344   367914       355829  0.006587
#
#                               amount  amount/i  clicks  clicks/i  dons/clicks  \
# B14_1028_frFR_dsk_ful_bt95  19474.59  0.054902    3561  0.010039     0.545914
# B14_1028_frFR_dsk_ful_btgy  22291.33  0.064371    4381  0.012651     0.496005
# B14_1028_frFR_dsk_ful_ctrl  19114.89  0.055329    3639  0.010533     0.509206
# B14_1028_frFR_dsk_ful_wydg  24173.12  0.067935    4410  0.012394     0.531519
#
#                             amount_ro  amount_ro/i     max  median        avg  \
# B14_1028_frFR_dsk_ful_bt95   17961.40     0.050636  630.49     6.3  10.017793
# B14_1028_frFR_dsk_ful_btgy   18193.09     0.052536  378.29     6.3  10.258320
# B14_1028_frFR_dsk_ful_ctrl   16340.69     0.047299  126.10     6.3  10.315645
# B14_1028_frFR_dsk_ful_wydg   22281.63     0.062619  630.49     6.3  10.312765
#
#                               avg_ro
# B14_1028_frFR_dsk_ful_bt95  9.277583
# B14_1028_frFR_dsk_ful_btgy  8.569520
# B14_1028_frFR_dsk_ful_ctrl  8.978401
# B14_1028_frFR_dsk_ful_wydg  9.550634

# %%
t_hive.get_traffic_stats(a, b, c, d)
# Out:
# result                                     hide                                \
# reason                      alterImpressionData         close  cookie  donate
# spider                                    False  True   False   False   False
# B14_1028_frFR_dsk_ful_bt95                 9779      5   8401      47    1201
# B14_1028_frFR_dsk_ful_btgy                 9687      2   8491      70    1182
# B14_1028_frFR_dsk_ful_ctrl                 4593      5   4889      66    1178
# B14_1028_frFR_dsk_ful_wydg                 4664     10   4976      52    1212
#
# result                        show         \
# reason                          na
# spider                       False  True
# B14_1028_frFR_dsk_ful_bt95  354716    231
# B14_1028_frFR_dsk_ful_btgy  346295    152
# B14_1028_frFR_dsk_ful_ctrl  345475    170
# B14_1028_frFR_dsk_ful_wydg  355829   1169
#
# result                      show;bcsi-ac-b5f45ffb1099c547=2362164F00000503A9SkDyhzudWo2xUG6EiA7RlsswqwAAAAAwUAAKNMCgAIBwAAWgAAAN0UBQA=  \
# reason                                                                                                                              na
# spider                                                                                                                           False
# B14_1028_frFR_dsk_ful_bt95                                                NaN
# B14_1028_frFR_dsk_ful_btgy                                                  1
# B14_1028_frFR_dsk_ful_ctrl                                                NaN
# B14_1028_frFR_dsk_ful_wydg                                                NaN
#
# result                      show;bcsi-ac-b5f45ffb1099c547=2362164F00000503XbL/z+3DvaCFptXvN/10jgyt9jazAAAAAwUAAGFxCgAIBwAAdAAAAFs5BQA=;bcsi-ac-95bb4efa6a1646c8=235F77BE000005038nkGToScOrAbbgmkGI17jLS8Q8XfAAAAAwUAAPcPDQAIBwAAFwAAAIfpBQA=  \
# reason                                                                                                                                                                                                                                    na
# spider                                                                                                                                                                                                                                 False
# B14_1028_frFR_dsk_ful_bt95                                                NaN
# B14_1028_frFR_dsk_ful_btgy                                                NaN
# B14_1028_frFR_dsk_ful_ctrl                                                NaN
# B14_1028_frFR_dsk_ful_wydg                                                  1
#
# result                      show;bcsi-ac-b5f45ffb1099c547=2362164F00000503u9hzZYMMoCly49YUYjUtOoMfvj6yAAAAAwUAAN1hCgAIBwAAWgAAALckBQA=  \
# reason                                                                                                                              na
# spider                                                                                                                           False
# B14_1028_frFR_dsk_ful_bt95                                                  1
# B14_1028_frFR_dsk_ful_btgy                                                NaN
# B14_1028_frFR_dsk_ful_ctrl                                                NaN
# B14_1028_frFR_dsk_ful_wydg                                                NaN
#
# result                      show;bcsi-ac-e7ec86c04da68444=235DA98A00000503/5tsxZsNGe79OM9aI297Fn8X7LX8AAAAAwUAABMwIQAIBwAAZAAAALeUAwA=  \
# reason                                                                                                                              na
# spider                                                                                                                           False
# B14_1028_frFR_dsk_ful_bt95                                                NaN
# B14_1028_frFR_dsk_ful_btgy                                                NaN
# B14_1028_frFR_dsk_ful_ctrl                                                NaN
# B14_1028_frFR_dsk_ful_wydg                                                  1
#
# result                      show;bcsi-ac-e7ec86c04da68444=235DA98A00000503KkO6JT0nJPGb8njAbt0QvazC2Fr8AAAAAwUAAIk4IQAIBwAAZQAAAPGeAwA=  \
# reason                                                                                                                              na
# spider                                                                                                                           False
# B14_1028_frFR_dsk_ful_bt95                                                NaN
# B14_1028_frFR_dsk_ful_btgy                                                  1
# B14_1028_frFR_dsk_ful_ctrl                                                NaN
# B14_1028_frFR_dsk_ful_wydg                                                NaN
#
# result                      show;bcsi-ac-e7ec86c04da68444=235DA98A00000503wsZYvAOSJFkTlZDepKNTex4NBuL8AAAAAwUAAB44IQAIBwAAZAAAAKqeAwA=  \
# reason                                                                                                                              na
# spider                                                                                                                           False
# B14_1028_frFR_dsk_ful_bt95                                                  1
# B14_1028_frFR_dsk_ful_btgy                                                NaN
# B14_1028_frFR_dsk_ful_ctrl                                                NaN
# B14_1028_frFR_dsk_ful_wydg                                                NaN
#
# result                      show;bcsi-ac-f36447ef44bbdc17=235F66C700000503KWC1oQF7LZ+OR3fZO8mEpTaME7jfAAAAAwUAAI8QDQAIBwAAWgAAAIgHBgA=
# reason                                                                                                                              na
# spider                                                                                                                           False
# B14_1028_frFR_dsk_ful_bt95                                                  1
# B14_1028_frFR_dsk_ful_btgy                                                NaN
# B14_1028_frFR_dsk_ful_ctrl                                                NaN
# B14_1028_frFR_dsk_ful_wydg                                                NaN

# %%
t_hive.plot_impressions(smooth = 1)

# %% [markdown]
# The fact that impressions dip, is totally expected since the banners were all fullscreen banners set to show up once per client

# %%
t_lutetium.plot_impressions(smooth = 10)

# %% [markdown]
# Since hive data is unsampled, it looks much cleaner. There is no notivable dip over time.

# %%
 t_hive.plot_show_hide(a, minutes = 30)

# %% [markdown]
# Here I've plotted the breakdown of result and reason fields over time. Notice how the number of hidden banners with reason=seen-fullscreen grows over time.

# %%
t_hive.rate_stats( a, b,c, d,  conf = 90, test = 'donations/impressions', plot = True)
# Out:
#                             P(Winner)      Winners Lift                    CI
# B14_1028_frFR_dsk_ful_wydg    0.95006    (0.00%, 0.00%)  (0.006367, 0.006814)
# B14_1028_frFR_dsk_ful_btgy    0.04994   (0.00%, 10.20%)  (0.006059, 0.006499)
# B14_1028_frFR_dsk_ful_bt95        NaN  (14.30%, 26.42%)  (0.005279, 0.005689)
# B14_1028_frFR_dsk_ful_ctrl        NaN  (16.69%, 29.21%)  (0.005164, 0.005571)

# %%
t_lutetium.rate_stats( a, b,c, d,  conf = 90, test = 'donations/impressions', plot = True)
# Out:
#                             P(Winner)      Winners Lift                    CI
# B14_1028_frFR_dsk_ful_wydg    0.99922    (0.00%, 0.00%)  (0.006294, 0.006736)
# B14_1028_frFR_dsk_ful_btgy    0.00078   (4.94%, 15.70%)  (0.005704, 0.006122)
# B14_1028_frFR_dsk_ful_bt95        NaN  (16.09%, 28.39%)  (0.005139, 0.005534)
# B14_1028_frFR_dsk_ful_ctrl        NaN  (21.80%, 35.00%)  (0.004887, 0.005277)
