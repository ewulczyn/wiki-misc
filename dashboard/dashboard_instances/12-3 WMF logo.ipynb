# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import pandas as pd
pd.options.display.mpl_style = 'default'

import inspect, os
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
os.sys.path.insert(0,parentdir) 
from src.dashboard_helpers import Test, custom_amount_stats
from src.data_retrieval import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
a = 'B14_120322_5C_lg_dsn_logo_n'
b = 'B14_120322_5C_lg_dsn_logo_y'

start = '2014-12-3 22:58'
stop = '2014-12-3 23:47'
 



t = Test(a, b, start = start, stop = stop)

# %%
t_hive = Test(a, b, hive = True, start = start, stop = stop)

# %%
t.ecom()
# Out:
#                              donations  impressions    dons/i    amount  \
# B14_120322_5C_lg_dsn_logo_n       2039       332400  0.006134  22082.52
# B14_120322_5C_lg_dsn_logo_y       2026       331700  0.006108  23308.55
#
#                              amount/i  clicks  clicks/i  dons/clicks  \
# B14_120322_5C_lg_dsn_logo_n  0.066434    3103  0.009335     0.657106
# B14_120322_5C_lg_dsn_logo_y  0.070270    3060  0.009225     0.662092
#
#                              amount_ro  amount_ro/i   max  median        avg  \
# B14_120322_5C_lg_dsn_logo_n   19174.90     0.057686   750       5  10.830074
# B14_120322_5C_lg_dsn_logo_y   20308.55     0.061226  3000       5  11.504714
#
#                                 avg_ro
# B14_120322_5C_lg_dsn_logo_n   9.492525
# B14_120322_5C_lg_dsn_logo_y  10.028914

# %%
t_hive.ecom()
# Out:
#                              donations  traffic  impressions    dons/i  \
# B14_120322_5C_lg_dsn_logo_n       2039   442157       332404  0.006134
# B14_120322_5C_lg_dsn_logo_y       2026   445062       332804  0.006088
#
#                                amount  amount/i  clicks  clicks/i  \
# B14_120322_5C_lg_dsn_logo_n  22082.52  0.066433    3103  0.009335
# B14_120322_5C_lg_dsn_logo_y  23308.55  0.070037    3060  0.009195
#
#                              dons/clicks  amount_ro  amount_ro/i   max  \
# B14_120322_5C_lg_dsn_logo_n     0.657106   19174.90     0.057686   750
# B14_120322_5C_lg_dsn_logo_y     0.662092   20308.55     0.061023  3000
#
#                              median        avg     avg_ro
# B14_120322_5C_lg_dsn_logo_n       5  10.830074   9.492525
# B14_120322_5C_lg_dsn_logo_y       5  11.504714  10.028914

# %%
t_hive.get_traffic_stats(a, b)
# Out:
# result                        hide                                           \
# reason                       close         cookie  cookies-disabled  donate
# spider                       False  True    False             False   False
# B14_120322_5C_lg_dsn_logo_n  80870    NaN     NaN              3267   10816
# B14_120322_5C_lg_dsn_logo_y  83257      2       4              3271   10289
#
# result                                                  na    show
# reason                       seen-fullscreen            na      na
# spider                                 False  True   False   False  True
# B14_120322_5C_lg_dsn_logo_n            13507     28      2  332404   1263
# B14_120322_5C_lg_dsn_logo_y            13414     27      1  332804   1993

# %%
t.plot_impressions( smooth = 1)

# %%
t_hive.plot_impressions()

# %%
t_hive.plot_show_hide(a, minutes = 5)

# %%
t_hive.plot_utm_key( max_key=5)

# %%
t.rate_stats(conf = 99)
# Out:
#                              P(Winner)     Winners Lift                    CI
# B14_120322_5C_lg_dsn_logo_n    0.55684   (0.00%, 0.00%)  (0.005792, 0.006491)
# B14_120322_5C_lg_dsn_logo_y    0.44316  (-7.26%, 9.03%)  (0.005762, 0.006467)

# %%
t_hive.rate_stats( conf = 99)
# Out:
#                              P(Winner)     Winners Lift                    CI
# B14_120322_5C_lg_dsn_logo_n    0.59642   (0.00%, 0.00%)  (0.005799, 0.006493)
# B14_120322_5C_lg_dsn_logo_y    0.40358  (-7.01%, 9.18%)  (0.005750, 0.006445)
