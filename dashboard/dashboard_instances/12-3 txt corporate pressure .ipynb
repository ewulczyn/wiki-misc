# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import pandas as pd
pd.options.display.mpl_style = 'default'

import inspect, os
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
os.sys.path.insert(0,parentdir) 
from src.dashboard_helpers import Test, custom_amount_stats
from src.data_retrieval import *

# %%
a = 'B14_120319_5C_lg_tx_cntr'
b = 'B14_120319_5C_lg_tx_corp'

start = '2014-12-3 12:25:00'
stop = '2014-12-3 20:52:00'
 



t = Test(a, b, start = start, stop = stop)

# %%
t_hive = Test(a, b, hive = True, start = start, stop = stop)

# %%
t.ecom()
# Out:
#                           donations  impressions    dons/i    amount  \
# B14_120319_5C_lg_tx_cntr       4501       791800  0.005685  49126.14
# B14_120319_5C_lg_tx_corp       4420       772300  0.005723  47307.25
#
#                           amount/i  clicks  clicks/i  dons/clicks  amount_ro  \
# B14_120319_5C_lg_tx_cntr  0.062044    7149  0.009029     0.629599   43070.82
# B14_120319_5C_lg_tx_corp  0.061255    7029  0.009101     0.628823   41004.13
#
#                           amount_ro/i  max  median        avg    avg_ro
# B14_120319_5C_lg_tx_cntr     0.054396  250       5  10.914495  9.694085
# B14_120319_5C_lg_tx_corp     0.053094  500       5  10.702998  9.395997

# %%
t_hive.ecom()
# Out:
#                           donations  traffic  impressions    dons/i    amount  \
# B14_120319_5C_lg_tx_cntr       4501   983311       778567  0.005781  49126.14
# B14_120319_5C_lg_tx_corp       4420   983858       777595  0.005684  47307.25
#
#                           amount/i  clicks  clicks/i  dons/clicks  amount_ro  \
# B14_120319_5C_lg_tx_cntr  0.063098    7149  0.009182     0.629599   43070.82
# B14_120319_5C_lg_tx_corp  0.060838    7029  0.009039     0.628823   41004.13
#
#                           amount_ro/i  max  median        avg    avg_ro
# B14_120319_5C_lg_tx_cntr     0.055321  250       5  10.914495  9.694085
# B14_120319_5C_lg_tx_corp     0.052732  500       5  10.702998  9.395997

# %%
t_hive.get_traffic_stats(a, b)
# Out:
# result                      hide                                           \
# reason                     close  cookie  cookies-disabled         donate
# spider                     False   False             False  True    False
# B14_120319_5C_lg_tx_cntr  145777     NaN              6820      4   20608
# B14_120319_5C_lg_tx_corp  145898       1              6752      7   20475
#
# result                                                      na    show
# reason                           seen-fullscreen            na      na
# spider                    True             False  True   False   False  True
# B14_120319_5C_lg_tx_cntr      3            29017     66     10  778567   2439
# B14_120319_5C_lg_tx_corp    NaN            29134     72      2  777595   3922

# %%
t.plot_impressions( smooth = 1)

# %%
t_hive.plot_impressions()

# %%
t_hive.plot_show_hide(a, minutes = 5)

# %%
t_hive.plot_utm_key( max_key=5)

# %%
t.rate_stats(conf = 99)
# Out:
#                           P(Winner)     Winners Lift                    CI
# B14_120319_5C_lg_tx_corp    0.62158   (0.00%, 0.00%)  (0.005507, 0.005948)
# B14_120319_5C_lg_tx_cntr    0.37842  (-4.61%, 6.39%)  (0.005468, 0.005907)

# %%
t_hive.rate_stats( conf = 99)
# Out:
#                           P(Winner)     Winners Lift                    CI
# B14_120319_5C_lg_tx_cntr    0.78748   (0.00%, 0.00%)  (0.005564, 0.006004)
# B14_120319_5C_lg_tx_corp    0.21252  (-3.69%, 7.34%)  (0.005471, 0.005904)
