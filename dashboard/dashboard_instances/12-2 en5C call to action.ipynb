# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import pandas as pd
pd.options.display.mpl_style = 'default'

import inspect, os
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
print parentdir
os.sys.path.insert(0,parentdir) 
from src.dashboard_helpers import Test, custom_amount_stats
from src.data_retrieval import *
import mpld3
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# /Users/ellerywulczyn/wmf/dashboard

# %%
a = 'B14_1203_5C_lg_cta_n'
b = 'B14_1203_5C_lg_cta_y'

t = Test(a, b, start = '2014-12-3 00:56',  stop ='2014-12-3 15:00' )

# %%
t.samples_per_banner(0.05)
# Out:
# 197520

# %%
t_hive = Test(a, b, hive = True, start = '2014-12-3 00:56',  stop ='2014-12-3 15:00')

# %%
t.ecom()
# Out:
#                       donations  impressions    dons/i     amount  amount/i  \
# B14_1203_5C_lg_cta_n      34698      4497500  0.007715  380053.78  0.084503
# B14_1203_5C_lg_cta_y      35876      4502100  0.007969  378179.56  0.084001
#
#                       clicks  clicks/i  dons/clicks  amount_ro  amount_ro/i  \
# B14_1203_5C_lg_cta_n   54608  0.012142     0.635401  325527.93     0.072380
# B14_1203_5C_lg_cta_y   55027  0.012223     0.651971  323757.96     0.071913
#
#                        max  median        avg    avg_ro
# B14_1203_5C_lg_cta_n  1000       5  10.953190  9.515578
# B14_1203_5C_lg_cta_y  1000       5  10.541297  9.148548

# %%
t_hive.ecom()
# Out:
#                       donations  traffic  impressions    dons/i     amount  \
# B14_1203_5C_lg_cta_n      34694  5913774      4492387  0.007723  380013.72
# B14_1203_5C_lg_cta_y      35865  5885250      4491607  0.007985  378042.94
#
#                       amount/i  clicks  clicks/i  dons/clicks  amount_ro  \
# B14_1203_5C_lg_cta_n  0.084591   54608  0.012156     0.635328  325487.87
# B14_1203_5C_lg_cta_y  0.084167   55027  0.012251     0.651771  323621.34
#
#                       amount_ro/i   max  median        avg    avg_ro
# B14_1203_5C_lg_cta_n     0.072453  1000       5  10.953298  9.515520
# B14_1203_5C_lg_cta_y     0.072050  1000       5  10.540720  9.147531

# %%
t_hive.get_traffic_stats(a, b)
# Out:
# result                  hide                                                  \
# reason                 close         cookie  cookies-disabled         donate
# spider                 False  True    False             False  True    False
# B14_1203_5C_lg_cta_n  971757      1      32             34631     15  118114
# B14_1203_5C_lg_cta_y  952666      2       1             34383     14  117562
#
# result                                                  na     show
# reason                       seen-fullscreen            na       na
# spider                True             False  True   False    False  True
# B14_1203_5C_lg_cta_n    NaN           275922    387      6  4492387  20522
# B14_1203_5C_lg_cta_y      2           275977    396      6  4491607  12634

# %%
fig = t.plot_impressions( smooth = 1)
mpld3.display(fig)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el188045007704484051285294"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el188045007704484051285294", {"axes": [{"xlim": [735570.0395833333, 735570.625], "yscale": "linear", "axesbg": "#EEEEEE", "texts": [{"v_baseline": "auto", "h_anchor": "middle", "color": "#555555", "text": "impressions", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 12.0, "position": [-0.069335237455197138, 0.5], "rotation": -90.0, "id": "el18804500656272"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#000000", "text": "None", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [-0.16129032258064516, -0.16129032258064518], "rotation": -0.0, "id": "el18804499539152"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#000000", "text": "B14_1203_5C_lg_cta_n", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 12.0, "position": [1.0795698924731183, 0.5170250896057349], "rotation": -0.0, "id": "el18804500125904"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#000000", "text": "B14_1203_5C_lg_cta_y", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 12.0, "position": [1.0795698924731183, 0.46594982078853048], "rotation": -0.0, "id": "el18804500210064"}], "zoomable": true, "images": [], "xdomain": [[2014, 11, 3, 0, 57, 0, 0.0], [2014, 11, 3, 15, 0, 0, 0.0]], "ylim": [0.0, 12000.0], "paths": [{"edgecolor": "#BCBCBC", "facecolor": "#EEEEEE", "edgewidth": 0.5, "pathcodes": ["M", "L", "S", "L", "S", "L", "S", "L", "S", "Z"], "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000001.0, "alpha": 1.0, "xindex": 0, "data": "data03", "id": "el18804500125328"}], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#000000", "alpha": 1.0, "dasharray": "2,2", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 7, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#000000", "alpha": 1.0, "dasharray": "2,2", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 7, "tickvalues": null}], "lines": [{"color": "#348ABD", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.0, "data": "data01", "id": "el18804503027920"}, {"color": "#7A68A6", "yindex": 2, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.0, "data": "data01", "id": "el18804500106896"}, {"color": "#348ABD", "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000002.0, "alpha": 1, "xindex": 0, "linewidth": 1.0, "data": "data02", "id": "el18804500104016"}, {"color": "#7A68A6", "yindex": 2, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000002.0, "alpha": 1, "xindex": 0, "linewidth": 1.0, "data": "data02", "id": "el18804500127248"}], "markers": [], "id": "el18804500545936", "ydomain": [0.0, 12000.0], "collections": [], "xscale": "date", "bbox": [0.125, 0.125, 0.77500000000000002, 0.77500000000000002]}], "height": 480.0, "width": 800.0, "plugins": [{"type": "reset"}, {"enabled": false, "button": true, "type": "zoom"}, {"enabled": false, "button": true, "type": "boxzoom"}], "data": {"data02": [[1.025806451612903, 0.5295698924731184, 0.478494623655914], [1.0559139784946237, 0.5295698924731184, 0.478494623655914]], "data03": [[1.01505376344086, 0.4435483870967742], [1.3380292338709676, 0.4435483870967742], [1.342330309139785, 0.4435483870967742], [1.342330309139785, 0.45071684587813615], [1.342330309139785, 0.5492831541218637], [1.342330309139785, 0.5564516129032258], [1.3380292338709676, 0.5564516129032258], [1.01505376344086, 0.5564516129032258], [1.0107526881720428, 0.5564516129032258], [1.0107526881720428, 0.5492831541218637], [1.0107526881720428, 0.45071684587813615], [1.0107526881720428, 0.4435483870967742], [1.01505376344086, 0.4435483870967742]], "data01": [[735570.0395833333, 2300.0, 1400.0], [735570.0402777778, 5000.0, 3900.0], [735570.0409722222, 2800.0, 4000.0], [735570.0416666666, 3600.0, 51 ...

# %%
t_hive.plot_impressions(a, b, smooth = 1)

# %%
t_hive.plot_show_hide(a, minutes = 30)

# %%
fig = t.plot_utm_key( max_key=5)

# %%
t.rate_stats(conf = 99)
# Out:
#                       P(Winner)    Winners Lift                    CI
# B14_1203_5C_lg_cta_y          1  (0.00%, 0.00%)  (0.007861, 0.008079)
# B14_1203_5C_lg_cta_n        NaN  (1.30%, 5.32%)  (0.007609, 0.007823)

# %%
t_hive.rate_stats(conf = 99)
# Out:
#                       P(Winner)    Winners Lift                    CI
# B14_1203_5C_lg_cta_y          1  (0.00%, 0.00%)  (0.007879, 0.008094)
# B14_1203_5C_lg_cta_n        NaN  (1.40%, 5.41%)  (0.007618, 0.007831)

# %%
t.amount_stats(a, b, conf = 99)
# Out:
# B14_1203_5C_lg_cta_n gives between $-2.0520 and $3.0291 more $/1000 impressions than B14_1203_5C_lg_cta_y

# %%
t.plot_donations_over_time(a,b, smooth = 30)

# %%
t.plot_impressions()
