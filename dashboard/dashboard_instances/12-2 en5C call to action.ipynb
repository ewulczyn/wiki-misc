# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import pandas as pd
pd.options.display.mpl_style = 'default'

import inspect, os
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
print parentdir
os.sys.path.insert(0,parentdir) 
from src.dashboard_helpers import Test, custom_amount_stats
from src.data_retrieval import *
# Out:
# /Users/ellerywulczyn/wmf/dashboard

# %%
a = 'B14_1203_5C_lg_cta_n'
b = 'B14_1203_5C_lg_cta_y'

t = Test(a, b, start = '2014-12-3 00:56',  stop ='2014-12-3 15:00' )

# %%
t.samples_per_banner(0.05)
# Out:
# 197520

# %%
t_hive = Test(a, b, hive = True, start = '2014-12-3 00:56',  stop ='2014-12-3 15:00')

# %%
t.ecom()
# Out:
#                       donations  impressions    dons/i     amount  amount/i  \
# B14_1203_5C_lg_cta_n      34694      4497500  0.007714  380013.72  0.084494
# B14_1203_5C_lg_cta_y      35865      4502100  0.007966  378042.94  0.083970
#
#                       clicks  clicks/i  dons/clicks  amount_ro  amount_ro/i  \
# B14_1203_5C_lg_cta_n   54608  0.012142     0.635328  325487.87     0.072371
# B14_1203_5C_lg_cta_y   55027  0.012223     0.651771  323621.34     0.071882
#
#                        max  median        avg    avg_ro
# B14_1203_5C_lg_cta_n  1000       5  10.953298  9.515520
# B14_1203_5C_lg_cta_y  1000       5  10.540720  9.147531

# %%
t_hive.ecom()
# Out:
#                       donations  traffic  impressions    dons/i     amount  \
# B14_1203_5C_lg_cta_n      34694  5913774      4492387  0.007723  380013.72
# B14_1203_5C_lg_cta_y      35865  5885250      4491607  0.007985  378042.94
#
#                       amount/i  clicks  clicks/i  dons/clicks  amount_ro  \
# B14_1203_5C_lg_cta_n  0.084591   54608  0.012156     0.635328  325487.87
# B14_1203_5C_lg_cta_y  0.084167   55027  0.012251     0.651771  323621.34
#
#                       amount_ro/i   max  median        avg    avg_ro
# B14_1203_5C_lg_cta_n     0.072453  1000       5  10.953298  9.515520
# B14_1203_5C_lg_cta_y     0.072050  1000       5  10.540720  9.147531

# %%
t_hive.get_traffic_stats(a, b)
# Out:
# result                  hide                                                  \
# reason                 close         cookie  cookies-disabled         donate
# spider                 False  True    False             False  True    False
# B14_1203_5C_lg_cta_n  971757      1      32             34631     15  118114
# B14_1203_5C_lg_cta_y  952666      2       1             34383     14  117562
#
# result                                                  na     show
# reason                       seen-fullscreen            na       na
# spider                True             False  True   False    False  True
# B14_1203_5C_lg_cta_n    NaN           275922    387      6  4492387  20522
# B14_1203_5C_lg_cta_y      2           275977    396      6  4491607  12634

# %%
t.plot_impressions( smooth = 1)

# %%
t_hive.plot_impressions(a, b, smooth = 1)

# %%
t_hive.plot_show_hide(a, minutes = 30)

# %%
t.plot_utm_key( max_key=5)

# %%
t.rate_stats(conf = 99)
# Out:
#                       P(Winner)    Winners Lift                    CI
# B14_1203_5C_lg_cta_y          1  (0.00%, 0.00%)  (0.007860, 0.008075)
# B14_1203_5C_lg_cta_n        NaN  (1.30%, 5.27%)  (0.007609, 0.007820)

# %%
t_hive.rate_stats(conf = 99)
# Out:
#                       P(Winner)    Winners Lift                    CI
# B14_1203_5C_lg_cta_y          1  (0.00%, 0.00%)  (0.007879, 0.008094)
# B14_1203_5C_lg_cta_n        NaN  (1.40%, 5.41%)  (0.007618, 0.007831)

# %%
t.amount_stats(a, b, conf = 99)
# Out:
# B14_1203_5C_lg_cta_n gives between $-2.0520 and $3.0291 more $/1000 impressions than B14_1203_5C_lg_cta_y

# %%
t.plot_donations_over_time(a,b, smooth = 30)

# %%
t.plot_impressions()
