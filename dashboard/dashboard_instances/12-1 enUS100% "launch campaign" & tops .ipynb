# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import pandas as pd
pd.options.display.mpl_style = 'default'

import inspect, os
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
os.sys.path.insert(0,parentdir) 
from src.dashboard_helpers import Test, custom_amount_stats
from src.data_retrieval import *

# %%
a = 'B14_120120_5c_hf_cpn_enUS'
b = 'B14_120120_5c_hf_hlp_enUS'
c = 'B14_120120_tp_tn1_enUS'
d = 'B14_120120_tp_tn2_enUS'
top = 'B14_1130_fl_tp_enUS'
t = Test(a, b, c, d, start = '2014-12-01 21:00', stop = '2014-12-01 22:00')

# %%
t_hive = Test(a, b, c, d, hive = True, start = '2014-12-01 21:00', stop = '2014-12-01 22:00')

# %%
t.ecom()
# Out:
#                            donations  impressions    dons/i    amount  \
# B14_120120_5c_hf_cpn_enUS       2132       517000  0.004124  27731.84
# B14_120120_5c_hf_hlp_enUS       2451       504100  0.004862  32830.00
# B14_120120_tp_tn1_enUS           762       688000  0.001108  10936.33
# B14_120120_tp_tn2_enUS           759       708000  0.001072   9367.27
#
#                            amount/i  clicks  clicks/i  dons/clicks  amount_ro  \
# B14_120120_5c_hf_cpn_enUS  0.053640    3344  0.006468     0.637560   22733.84
# B14_120120_5c_hf_hlp_enUS  0.065126    3747  0.007433     0.654123   26030.00
# B14_120120_tp_tn1_enUS     0.015896    1209  0.001757     0.630273    9936.33
# B14_120120_tp_tn2_enUS     0.013231    1209  0.001708     0.627792    8267.27
#
#                            amount_ro/i   max  median        avg     avg_ro
# B14_120120_5c_hf_cpn_enUS     0.043973   300       5  13.007430  10.908752
# B14_120120_5c_hf_hlp_enUS     0.051637  1000       5  13.394533  10.845833
# B14_120120_tp_tn1_enUS        0.014442  1000       5  14.352139  13.056938
# B14_120120_tp_tn2_enUS        0.011677   100       5  12.341594  11.052500

# %%
t_hive.ecom()
# Out:
#                            donations  traffic  impressions    dons/i  \
# B14_120120_5c_hf_cpn_enUS       2134   586732       515471  0.004140
# B14_120120_5c_hf_hlp_enUS       2454   585265       514971  0.004765
# B14_120120_tp_tn1_enUS           762   773845       668984  0.001139
# B14_120120_tp_tn2_enUS           760   828015       711086  0.001069
#
#                              amount  amount/i  clicks  clicks/i  dons/clicks  \
# B14_120120_5c_hf_cpn_enUS  27744.84  0.053824    3344  0.006487     0.638158
# B14_120120_5c_hf_hlp_enUS  32880.00  0.063848    3747  0.007276     0.654924
# B14_120120_tp_tn1_enUS     10936.33  0.016348    1209  0.001807     0.630273
# B14_120120_tp_tn2_enUS      9387.27  0.013201    1209  0.001700     0.628619
#
#                            amount_ro  amount_ro/i   max  median        avg  \
# B14_120120_5c_hf_cpn_enUS   22746.84     0.044128   300       5  13.001331
# B14_120120_5c_hf_hlp_enUS   26080.00     0.050644  1000       5  13.398533
# B14_120120_tp_tn1_enUS       9936.33     0.014853  1000       5  14.352139
# B14_120120_tp_tn2_enUS       8287.27     0.011654   100       5  12.351671
#
#                               avg_ro
# B14_120120_5c_hf_cpn_enUS  10.904525
# B14_120120_5c_hf_hlp_enUS  10.853100
# B14_120120_tp_tn1_enUS     13.056938
# B14_120120_tp_tn2_enUS     11.064446

# %%
t_hive.get_traffic_stats(a, b, c, d)
# Out:
# result                       hide                                    \
# reason                      close  cookie  cookies-disabled  donate
# spider                      False   False             False   False
# B14_120120_5c_hf_cpn_enUS   49991       1              4114    8177
# B14_120120_5c_hf_hlp_enUS   49468     NaN              4046    7743
# B14_120120_tp_tn1_enUS      99269     NaN               NaN    5122
# B14_120120_tp_tn2_enUS     111754     NaN               NaN    4731
#
# result                                                na           show
# reason                     seen-fullscreen             c     na      na
# spider                               False  True   False  False   False  True
# B14_120120_5c_hf_cpn_enUS             8011     28      1      4  515471    934
# B14_120120_5c_hf_hlp_enUS             7772     17    NaN    NaN  514971   1248
# B14_120120_tp_tn1_enUS                 NaN    NaN    NaN    NaN  668984    470
# B14_120120_tp_tn2_enUS                 NaN    NaN    NaN      7  711086    437

# %%
t.plot_impressions(a, b, c, d, smooth = 2)

# %%
t_hive.plot_impressions(a, b, c, d, smooth = 1
                    )

# %%
t_hive.plot_show_hide(a)

# %%
t_hive.plot_show_hide(b)

# %%
t_hive.plot_show_hide(c)

# %%
t.plot_utm_key(a, b, c, d, max_key=5)

# %%
t_hive.rate_stats()
# Out:
#                            P(Winner)        Winners Lift                    CI
# B14_120120_5c_hf_hlp_enUS          1      (0.00%, 0.00%)  (0.004581, 0.004957)
# B14_120120_5c_hf_cpn_enUS        NaN     (8.58%, 21.99%)  (0.003967, 0.004319)
# B14_120120_tp_tn1_enUS           NaN  (285.90%, 353.50%)  (0.001061, 0.001223)
# B14_120120_tp_tn2_enUS           NaN  (311.39%, 383.58%)  (0.000996, 0.001147)

# %%
t.rate_stats()
# Out:
#                            P(Winner)        Winners Lift                    CI
# B14_120120_5c_hf_hlp_enUS          1      (0.00%, 0.00%)  (0.004672, 0.005060)
# B14_120120_5c_hf_cpn_enUS        NaN    (11.26%, 24.94%)  (0.003953, 0.004302)
# B14_120120_tp_tn1_enUS           NaN  (304.51%, 375.85%)  (0.001032, 0.001189)
# B14_120120_tp_tn2_enUS           NaN  (318.09%, 392.00%)  (0.000999, 0.001151)
