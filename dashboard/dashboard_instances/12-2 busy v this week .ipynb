# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import pandas as pd
pd.options.display.mpl_style = 'default'

import inspect, os
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
print parentdir
os.sys.path.insert(0,parentdir) 
from src.dashboard_helpers import Test, custom_amount_stats
from src.data_retrieval import *
# Out:
# /Users/ellerywulczyn/wmf/dashboard

# %%
a = 'B14_120221_5C_lg_by'
b = 'B14_120221_5C_lg_tw'
t = Test(a, b, start = '2014-12-2-21:30', stop = '2014-12-2-23:30')

# %%
t.samples_per_banner(0.05)
# Out:
# 197520

# %%
t.plot_donations_over_time()

# %%
t_hive = Test(a, b, hive = True, start = '2014-12-2-21:30', stop = '2014-12-2-23:30')

# %%
t.ecom()
# Out:
#                      donations  impressions    dons/i    amount  amount/i  \
# B14_120221_5C_lg_by       8368      1069900  0.007821  94351.17  0.088187
# B14_120221_5C_lg_tw       7544      1075500  0.007014  87077.53  0.080965
#
#                      clicks  clicks/i  dons/clicks  amount_ro  amount_ro/i  \
# B14_120221_5C_lg_by   13093  0.012238     0.639120   81041.28     0.075747
# B14_120221_5C_lg_tw   11775  0.010948     0.640679   74077.30     0.068877
#
#                      max  median        avg    avg_ro
# B14_120221_5C_lg_by  500       5  11.275235  9.838689
# B14_120221_5C_lg_tw  500       5  11.542621  9.976741

# %%
t_hive.ecom()
# Out:
#                      donations  traffic  impressions    dons/i    amount  \
# B14_120221_5C_lg_by       8368  1399159      1071998  0.007806  94351.17
# B14_120221_5C_lg_tw       7544  1397817      1069254  0.007055  87077.53
#
#                      amount/i  clicks  clicks/i  dons/clicks  amount_ro  \
# B14_120221_5C_lg_by  0.088014   13093  0.012214     0.639120   81041.28
# B14_120221_5C_lg_tw  0.081438   11775  0.011012     0.640679   74077.30
#
#                      amount_ro/i  max  median        avg    avg_ro
# B14_120221_5C_lg_by     0.075598  500       5  11.275235  9.838689
# B14_120221_5C_lg_tw     0.069279  500       5  11.542621  9.976741

# %%
t_hive.get_traffic_stats(a, b)
# Out:
# result                 hide                                           \
# reason                close  cookie  cookies-disabled         donate
# spider                False   False             False  True    False
# B14_120221_5C_lg_by  208886       2              6953      4   24213
# B14_120221_5C_lg_tw  207261       1              6912      1   25073
#
# result                                          na     show
# reason               seen-fullscreen            na       na
# spider                         False  True   False    False  True
# B14_120221_5C_lg_by            84207     88      4  1071998   2804
# B14_120221_5C_lg_tw            84738     87      7  1069254   4483

# %%
t.plot_impressions( smooth = 1, start = '2014-12-2-21:30', stop = '2014-12-2-23:30')

# %%
t_hive.plot_impressions(a, b, smooth = 1)

# %%
t_hive.plot_show_hide(a, minutes = 5)

# %%
t_hive.plot_show_hide(b)

# %%
t.plot_utm_key( max_key=5)

# %%
t.rate_stats(conf = 99)
# Out:
#                      P(Winner)     Winners Lift                    CI
# B14_120221_5C_lg_by          1   (0.00%, 0.00%)  (0.007604, 0.008041)
# B14_120221_5C_lg_tw        NaN  (7.07%, 16.10%)  (0.006812, 0.007226)

# %%
t_hive.rate_stats(conf = 99)
# Out:
#                      P(Winner)     Winners Lift                    CI
# B14_120221_5C_lg_by          1   (0.00%, 0.00%)  (0.007593, 0.008030)
# B14_120221_5C_lg_tw        NaN  (6.24%, 15.30%)  (0.006846, 0.007268)
