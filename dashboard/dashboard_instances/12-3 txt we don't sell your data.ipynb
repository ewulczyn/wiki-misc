# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import pandas as pd
pd.options.display.mpl_style = 'default'

import inspect, os
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
os.sys.path.insert(0,parentdir) 
from src.dashboard_helpers import Test, custom_amount_stats
from src.data_retrieval import *

# %%
a = 'B14_120317_5C_lg_tx_ear'
b = 'B14_120317_5C_lg_tx_ind'

start = '2014-12-3 18:30:00'
stop = '2014-12-3 19:24:00'
 



t = Test(a, b, start = start, stop = stop)
# Out:
# /Users/ellerywulczyn/wmf/util/query_remote_from_local_utils.py:23: Warning: Truncated incorrect INTEGER value: '1�'
#   cursor.execute(query, params)

# %%
t_hive = Test(a, b, hive = True, start = start, stop = stop)

# %%
t.ecom()
# Out:
#                          donations  impressions    dons/i    amount  amount/i  \
# B14_120317_5C_lg_tx_ear       2868       511400  0.005608  29698.48  0.058073
# B14_120317_5C_lg_tx_ind       2939       497500  0.005908  32359.38  0.065044
#
#                          clicks  clicks/i  dons/clicks  amount_ro  \
# B14_120317_5C_lg_tx_ear    4615  0.009024     0.621452   25966.67
# B14_120317_5C_lg_tx_ind    4785  0.009618     0.614211   28122.65
#
#                          amount_ro/i     max  median        avg    avg_ro
# B14_120317_5C_lg_tx_ear     0.050776  156.96       5  10.355119  9.172261
# B14_120317_5C_lg_tx_ind     0.056528  500.00       5  11.010337  9.694123

# %%
t_hive.ecom()
# Out:
#                          donations  traffic  impressions    dons/i    amount  \
# B14_120317_5C_lg_tx_ear       2868   630839       503647  0.005694  29698.48
# B14_120317_5C_lg_tx_ind       2939   631446       504446  0.005826  32359.38
#
#                          amount/i  clicks  clicks/i  dons/clicks  amount_ro  \
# B14_120317_5C_lg_tx_ear  0.058967    4615  0.009163     0.621452   25966.67
# B14_120317_5C_lg_tx_ind  0.064148    4785  0.009486     0.614211   28122.65
#
#                          amount_ro/i     max  median        avg    avg_ro
# B14_120317_5C_lg_tx_ear     0.051557  156.96       5  10.355119  9.172261
# B14_120317_5C_lg_tx_ind     0.055750  500.00       5  11.010337  9.694123

# %%
t_hive.get_traffic_stats(a, b)
# Out:
# result                    hide                                          \
# reason                   close  cookies-disabled         donate
# spider                   False             False  True    False  True
# B14_120317_5C_lg_tx_ear  89788              4131      1   12104    NaN
# B14_120317_5C_lg_tx_ind  89808              4154    NaN   12745      1
#
# result                                              na    show
# reason                   seen-fullscreen            na      na
# spider                             False  True   False   False  True
# B14_120317_5C_lg_tx_ear            18944     37      2  503647   2185
# B14_120317_5C_lg_tx_ind            18789     26      3  504446   1474

# %%
t.plot_impressions( smooth = 1)

# %%
t_hive.plot_impressions()

# %%
t_hive.plot_show_hide(a, minutes = 5)

# %%
t_hive.plot_utm_key( max_key=5)

# %%
t.rate_stats(conf = 99)
# Out:
#                          P(Winner)      Winners Lift                    CI
# B14_120317_5C_lg_tx_ind    0.97704    (0.00%, 0.00%)  (0.005632, 0.006196)
# B14_120317_5C_lg_tx_ear    0.02296  (-1.54%, 12.63%)  (0.005347, 0.005886)

# %%
t_hive.rate_stats( conf = 99)
# Out:
#                          P(Winner)     Winners Lift                    CI
# B14_120317_5C_lg_tx_ind    0.80692   (0.00%, 0.00%)  (0.005557, 0.006104)
# B14_120317_5C_lg_tx_ear    0.19308  (-4.27%, 9.26%)  (0.005432, 0.005973)
