# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import pandas as pd
pd.options.display.mpl_style = 'default'

import inspect, os
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
os.sys.path.insert(0,parentdir) 
from src.dashboard_helpers import Test, custom_amount_stats
from src.data_retrieval import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
a = 'B14_120217_5C_lg_n_bgft'
b = 'B14_120217_5C_lg_n_smby'
c = 'B14_120217_5C_lg_n_smne'
d = 'B14_120217_5C_lg_y_smft'
e = 'B14_120217_5C_tp_tn1'
f = 'B14_120217_5C_tp_tn2'


t = Test(a, b, c, d, e, f, start = '2014-12-02 19:07', stop = '2014-12-02 21:36')

# %%
t_hive = Test(a, b, c, d, hive = True, start = '2014-12-02 19:07',stop = '2014-12-02 21:36')

# %%
t.ecom()
# Out:
#                          donations  impressions    dons/i    amount  amount/i  \
# B14_120217_5C_lg_n_bgft       5423       825300  0.006571  62007.96  0.075134
# B14_120217_5C_lg_n_smby       4576       840400  0.005445  53108.30  0.063194
# B14_120217_5C_lg_n_smne       4242       842100  0.005037  52244.19  0.062040
# B14_120217_5C_lg_y_smft       4570       819000  0.005580  53016.50  0.064733
# B14_120217_5C_tp_tn1          2444      2374000  0.001029  29471.22  0.012414
# B14_120217_5C_tp_tn2          2583      2427200  0.001064  29365.81  0.012099
#
#                          clicks  clicks/i  dons/clicks  amount_ro  \
# B14_120217_5C_lg_n_bgft    8763  0.010618     0.618852   53636.01
# B14_120217_5C_lg_n_smby    7287  0.008671     0.627968   46022.15
# B14_120217_5C_lg_n_smne    6784  0.008056     0.625295   44096.10
# B14_120217_5C_lg_y_smft    7448  0.009094     0.613588   45182.27
# B14_120217_5C_tp_tn1       4211  0.001774     0.580385   24117.14
# B14_120217_5C_tp_tn2       4434  0.001827     0.582544   25448.25
#
#                          amount_ro/i   max  median        avg     avg_ro
# B14_120217_5C_lg_n_bgft     0.064990   200       5  11.434254  10.040436
# B14_120217_5C_lg_n_smby     0.054762   250       5  11.605835  10.208995
# B14_120217_5C_lg_n_smne     0.052364  1000       5  12.315934  10.572069
# B14_120217_5C_lg_y_smft     0.055168  1000       5  11.600985  10.040504
# B14_120217_5C_tp_tn1        0.010159   500       5  12.058601  10.052997
# B14_120217_5C_tp_tn2        0.010485   352       5  11.368877   9.991461

# %%
t_hive.ecom()
# Out:
#                          donations  traffic  impressions    dons/i    amount  \
# B14_120217_5C_lg_n_bgft       5423  1088014       841290  0.006446  62007.96
# B14_120217_5C_lg_n_smby       4576  1074884       834643  0.005483  53108.30
# B14_120217_5C_lg_n_smne       4242  1085891       843294  0.005030  52244.19
# B14_120217_5C_lg_y_smft       4570  1076992       833074  0.005486  53016.50
#
#                          amount/i  clicks  clicks/i  dons/clicks  amount_ro  \
# B14_120217_5C_lg_n_bgft  0.073706    8763  0.010416     0.618852   53636.01
# B14_120217_5C_lg_n_smby  0.063630    7287  0.008731     0.627968   46022.15
# B14_120217_5C_lg_n_smne  0.061953    6784  0.008045     0.625295   44096.10
# B14_120217_5C_lg_y_smft  0.063640    7448  0.008940     0.613588   45182.27
#
#                          amount_ro/i   max  median        avg     avg_ro
# B14_120217_5C_lg_n_bgft     0.063754   200       5  11.434254  10.040436
# B14_120217_5C_lg_n_smby     0.055140   250       5  11.605835  10.208995
# B14_120217_5C_lg_n_smne     0.052290  1000       5  12.315934  10.572069
# B14_120217_5C_lg_y_smft     0.054236  1000       5  11.600985  10.040504

# %%
t_hive.get_traffic_stats(a, b, c, d)
# Out:
# result                     hide                                           \
# reason                    close  cookie  cookies-disabled         donate
# spider                    False   False             False  True    False
# B14_120217_5C_lg_n_bgft  149826     NaN              4739      3   16310
# B14_120217_5C_lg_n_smby  147253     NaN              4765      3   15752
# B14_120217_5C_lg_n_smne  148009     NaN              4596      2   16238
# B14_120217_5C_lg_y_smft  150265       1              4540      3   16218
#
# result                                              na    show
# reason                   seen-fullscreen            na      na
# spider                             False  True   False   False  True
# B14_120217_5C_lg_n_bgft            71833     76      2  841290   3935
# B14_120217_5C_lg_n_smby            70579     56      3  834643   1830
# B14_120217_5C_lg_n_smne            71854     70      5  843294   1823
# B14_120217_5C_lg_y_smft            71038     64      1  833074   1788

# %%
t.plot_impressions( smooth = 1, stop = '2014-12-02 21:36')

# %%
t_hive.plot_impressions(a, b, c, d, smooth = 1)

# %%
t_hive.plot_show_hide(a, minutes = 5)

# %%
t_hive.plot_utm_key( max_key=5)

# %%
t.rate_stats(a, b, c, d, conf = 99)
# Out:
#                          P(Winner)      Winners Lift                    CI
# B14_120217_5C_lg_n_bgft          1    (0.00%, 0.00%)  (0.006343, 0.006804)
# B14_120217_5C_lg_n_smby        NaN  (14.63%, 26.99%)  (0.005243, 0.005657)
# B14_120217_5C_lg_n_smne        NaN  (23.76%, 37.37%)  (0.004845, 0.005242)
# B14_120217_5C_lg_y_smft        NaN  (11.79%, 23.93%)  (0.005375, 0.005797)

# %%
t_hive.rate_stats( conf = 99)
# Out:
#                          P(Winner)      Winners Lift                    CI
# B14_120217_5C_lg_n_bgft          1    (0.00%, 0.00%)  (0.006224, 0.006672)
# B14_120217_5C_lg_n_smby        NaN  (11.71%, 23.78%)  (0.005280, 0.005692)
# B14_120217_5C_lg_n_smne        NaN  (21.64%, 35.09%)  (0.004836, 0.005230)
# B14_120217_5C_lg_y_smft        NaN  (11.63%, 23.66%)  (0.005279, 0.005696)
