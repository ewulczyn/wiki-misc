# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import pandas as pd
pd.options.display.mpl_style = 'default'

import inspect, os
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
os.sys.path.insert(0,parentdir) 
from src.dashboard_helpers import Test, custom_amount_stats
from src.data_retrieval import *

# %%
a = 'B14_120315_5C_lg_fnt_lg'
b = 'B14_120315_5C_lg_fnt_sm'
start = '2014-12-3 15:49:00'
stop = '2014-12-3 16:29:00'
 



t = Test(a, b, start = start, stop = stop)

# %%
t_hive = Test(a, b, hive = True, start = start, stop = stop)

# %%
t.ecom()
# Out:
#                          donations  impressions    dons/i    amount  amount/i  \
# B14_120315_5C_lg_fnt_lg       1909       323500  0.005901  20611.02  0.063713
# B14_120315_5C_lg_fnt_sm       2048       327100  0.006261  23244.97  0.071064
#
#                          clicks  clicks/i  dons/clicks  amount_ro  \
# B14_120315_5C_lg_fnt_lg    3012  0.009311     0.633798   18197.42
# B14_120315_5C_lg_fnt_sm    3263  0.009976     0.627643   19529.53
#
#                          amount_ro/i     max  median        avg    avg_ro
# B14_120315_5C_lg_fnt_lg     0.056252  156.96       5  10.796763  9.653804
# B14_120315_5C_lg_fnt_sm     0.059705  250.00       5  11.350083  9.706526

# %%
t_hive.ecom()
# Out:
#                          donations  traffic  impressions    dons/i    amount  \
# B14_120315_5C_lg_fnt_lg       1909   393824       323924  0.005893  20611.02
# B14_120315_5C_lg_fnt_sm       2048   394545       323801  0.006325  23244.97
#
#                          amount/i  clicks  clicks/i  dons/clicks  amount_ro  \
# B14_120315_5C_lg_fnt_lg  0.063629    3012  0.009298     0.633798   18197.42
# B14_120315_5C_lg_fnt_sm  0.071788    3263  0.010077     0.627643   19529.53
#
#                          amount_ro/i     max  median        avg    avg_ro
# B14_120315_5C_lg_fnt_lg     0.056178  156.96       5  10.796763  9.653804
# B14_120315_5C_lg_fnt_sm     0.060313  250.00       5  11.350083  9.706526

# %%
t_hive.get_traffic_stats(a, b)
# Out:
# result                    hide                                   \
# reason                   close  cookies-disabled         donate
# spider                   False             False  True    False
# B14_120315_5C_lg_fnt_lg  45699              2476      1    6866
# B14_120315_5C_lg_fnt_sm  47225              2408      2    6747
#
# result                                              na    show
# reason                   seen-fullscreen            na      na
# spider                             False  True   False   False  True
# B14_120315_5C_lg_fnt_lg            13564     20      1  323924   1273
# B14_120315_5C_lg_fnt_sm            13526     27    NaN  323801    809

# %%
t.plot_impressions( smooth = 1, stop = stop)

# %%
t_hive.plot_impressions(a, b, smooth = 1)

# %%
t_hive.plot_show_hide(a, minutes = 5)

# %%
t_hive.plot_utm_key( max_key=5)

# %%
t.rate_stats(conf = 99)
# Out:
#                          P(Winner)      Winners Lift                    CI
# B14_120315_5C_lg_fnt_sm    0.96926    (0.00%, 0.00%)  (0.005917, 0.006632)
# B14_120315_5C_lg_fnt_lg    0.03074  (-2.19%, 15.26%)  (0.005564, 0.006257)

# %%
t_hive.rate_stats(a, b, conf = 99)
# Out:
#                          P(Winner)      Winners Lift                    CI
# B14_120315_5C_lg_fnt_sm    0.98678    (0.00%, 0.00%)  (0.005973, 0.006701)
# B14_120315_5C_lg_fnt_lg    0.01322  (-1.17%, 16.48%)  (0.005554, 0.006247)
