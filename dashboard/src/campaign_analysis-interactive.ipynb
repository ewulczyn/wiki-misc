# %%
# %matplotlib inline
import matplotlib.pyplot as plt # side-stepping mpl backend
import matplotlib.gridspec as gridspec # subplots
import numpy as np
from IPython.html.widgets import interact
import plotly.plotly as py
import plotly.tools as tls
from plotly.graph_objs import *
py.sign_in("ewulczyn", "y2a7n75kl8")

# %%
def sinplot(flip=1):
    x = np.linspace(0, 14, 100)
    for i in range(1, 7):
        ppl.plot(x, np.sin(x + i * .5) * (7 - i) * flip)

# %%
def interactive_sinplot(flip=1):
    fig14 = plt.figure()

    x = np.linspace(0, 14, 100)
    for i in range(1, 7):
        ppl.plot(x, np.sin(x + i * .5) * (7 - i) * flip)
    return py.iplot_mpl(fig14, strip_style = True)

# %%
fig14 = plt.figure()
sinplot()

py.iplot_mpl(fig14, strip_style = True)

# %%
interactive_sinplot()

# %%
from IPython.html import widgets # Widget definitions
mywidget = widgets.FloatSliderWidget()
mywidget.max = 10

interact(interactive_sinplot, flip=mywidget);
