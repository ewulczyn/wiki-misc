# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import pandas as pd
pd.options.display.mpl_style = 'default'

import plotly.plotly as py
import plotly.tools as tls
from plotly.graph_objs import *
py.sign_in("ewulczyn", "y2a7n75kl8")

from banner_count import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
start = '2014-11-30 00:00'
stop = '2014-12-07 23:59'

don = get_donations_by_banner_count(start, stop)

# %%
start = '2014-11-30'
stop = '2014-12-07'

imp = get_impressions_by_banner_count(start, stop)

# %% [markdown]
# # What Impression Readers are on broken down by day

# %%
regs = {
        'Dec 7': '.* C14_en5C_dec_dsk_FR 2014-12-07',
        'Dec 5': '.* C14_en5C_dec_dsk_FR 2014-12-05',
        'Dec 2': '.* C14_en5C_dec_dsk_FR 2014-12-02'
       }

fig = plot_by_impressions_seen(imp, regs ,normalize = True ,max_impressions = 10)
py.iplot_mpl(fig, strip_style = True)

# %% [markdown]
# # What Impression Readers are on broken down by banner type

# %%
regs = {
        'Large': '.*5C_lg.* C14_en5C_dec_dsk_FR',
        'Top': '.* C14_en5C_dec_dsk_FR',
       }

fig = plot_by_impressions_seen(imp,regs,normalize = True ,max_impressions = 10)
py.iplot_mpl(fig, strip_style = True)

# %% [markdown]
# # What Impression Readers are on broken down by banner type and day

# %% [markdown]
# ### Large

# %%
regs = {
        'Large Dec 7': '.*5C_lg.* C14_en5C_dec_dsk_FR 2014-12-07',
        'Large Dec 5': '.*5C_lg.* C14_en5C_dec_dsk_FR 2014-12-05',
        'Large Dec 2': '.*5C_lg.* C14_en5C_dec_dsk_FR 2014-12-03'
       }


fig = plot_by_impressions_seen(imp,regs, normalize = True ,max_impressions = 10)

# %% [markdown]
# ###Top

# %%
regs = {
        'Top Dec 7': '.*5C_tp.* C14_en5C_dec_dsk_FR 2014-12-07',
        'Top Dec 5': '.*5C_tp.* C14_en5C_dec_dsk_FR 2014-12-05',
        'Top Dec 2': '.*5C_tp.* C14_en5C_dec_dsk_FR 2014-12-03'
       }


fig = plot_by_impressions_seen(imp,regs, normalize = True ,max_impressions = 10)

# %% [markdown]
# #Donation rate broken down by banner count

# %%
regs ={
#'Large': '.*5C_lg.* C14_en5C_dec_dsk_FR',
'Top': '.*5C_tp.* C14_en5C_dec_dsk_FR '
}

fig = plot_donation_rate(don, imp, regs, cum = False ,max_impressions = 20)
py.iplot_mpl(fig, strip_style = True)

# %% [markdown]
# #Donation rate broken down by banner count and day

# %% [markdown]
# ###Large

# %%
regs = {
        'Large Dec 7': '.*5C_lg.* C14_en5C_dec_dsk_FR 2014-12-07',
        'Large Dec 5': '.*5C_lg.* C14_en5C_dec_dsk_FR 2014-12-05',
        'Large Dec 2': '.*5C_lg.* C14_en5C_dec_dsk_FR 2014-12-03'
       }

fig = plot_donation_rate(don, imp, regs, cum = False ,max_impressions = 10)
#py.iplot_mpl(fig, strip_style = True)

# %% [markdown]
# ###Top

# %%
regs = {
        'Top Dec 7': '.*5C_tp.* C14_en5C_dec_dsk_FR 2014-12-07',
        'Top Dec 5': '.*5C_tp.* C14_en5C_dec_dsk_FR 2014-12-05',
        'Top Dec 2': '.*5C_tp.* C14_en5C_dec_dsk_FR 2014-12-03'
       }
fig = plot_donation_rate(don, imp, regs, cum = False ,max_impressions = 10)
py.iplot_mpl(fig, strip_style = True)

# %%
regs = {
        #'Large': '.*5C_lg.* C14_en5C_dec_dsk_FR',
        'Top': '.* C14_en5C_dec_dsk_FR',
       }

fig = plot_by_impressions_seen(don,regs,normalize = True ,max_impressions = 10)
py.iplot_mpl(fig, strip_style = True)
