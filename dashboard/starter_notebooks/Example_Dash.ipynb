# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import pandas as pd
pd.options.display.mpl_style = 'default'

import inspect, os
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
print parentdir

os.sys.path.insert(0,parentdir) 
from src.dashboard_helpers import Test
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# /Users/ellerywulczyn/wmf/dashboard

# %%
t = Test("B14_1015_enBE_dsk_full_nn", "B14_1015_enBE_dsk_full_y1", "B14_1015_enBE_dsk_full_y2", start = '2014-10-10')

# %%
t.combine(["B14_1015_enBE_dsk_full_y1", "B14_1015_enBE_dsk_full_y2"], 'B14_1015_enBE_dsk_full_y')
t.combine(["B14_1015_enBE_dsk_full_nn", "B14_1015_enBE_dsk_full_y1", "B14_1015_enBE_dsk_full_y2"], 'all')

# %%
t.ecom("B14_1015_enBE_dsk_full_nn", "B14_1015_enBE_dsk_full_y")
# Out:
#                            donations  impressions    dons/i    amount  \
# B14_1015_enBE_dsk_full_nn       2892      3605500  0.000802  34785.19
# B14_1015_enBE_dsk_full_y        4998      3655500  0.001367  55583.38
#
#                            amount/i  clicks  clicks/i  dons/clicks  amount_ro  \
# B14_1015_enBE_dsk_full_nn  0.009648    5035  0.001396     0.574379   27391.14
# B14_1015_enBE_dsk_full_y   0.015205    9257  0.002532     0.539916   44809.98
#
#                            amount_ro/i     max  median        avg    avg_ro
# B14_1015_enBE_dsk_full_nn     0.007597  190.42    6.38  12.028074  9.796545
# B14_1015_enBE_dsk_full_y      0.012258  159.70    6.36  11.121124  9.239171

# %%
t.get_payment_method_details()
# Out:
#                                    donations  clicks  conversion_rate  \
# B14_1015_enBE_dsk_full_nn cc             903    2106        42.877493
#                           paypal        1948    2749        70.862132
#                           rcc             16      97        16.494845
#                           rpaypal         25      83        30.120482
# B14_1015_enBE_dsk_full_y  cc            1633    3873        42.163697
#                           paypal        3275    5028        65.135243
#                           rcc             51     206        24.757282
#                           rpaypal         39     150        26.000000
# B14_1015_enBE_dsk_full_y1 cc            1037    2501        41.463415
#                           paypal        2111    3245        65.053929
#                           rcc             40     138        28.985507
#                           rpaypal         25     110        22.727273
# B14_1015_enBE_dsk_full_y2 cc             596    1372        43.440233
#                           paypal        1164    1783        65.283231
#                           rcc             11      68        16.176471
#                           rpaypal         14      40        35.000000
# all                       cc            2536    5979        42.415120
#                           paypal        5223    7777        67.159573
#                           rcc             67     303        22.112211
#                           rpaypal         64     233        27.467811
#
#                                    percent clicked on  percent donated on  \
# B14_1015_enBE_dsk_full_nn cc                41.827210           31.224066
#                           paypal            54.597815           67.358230
#                           rcc                1.926514            0.553250
#                           rpaypal            1.648461            0.864454
# B14_1015_enBE_dsk_full_y  cc                41.838609           32.673069
#                           paypal            54.315653           65.526210
#                           rcc                2.225343            1.020408
#                           rpaypal            1.620395            0.780312
# B14_1015_enBE_dsk_full_y1 cc                41.725058           32.275132
#                           paypal            54.137471           65.701836
#                           rcc                2.302302            1.244942
#                           rpaypal            1.835169            0.778089
# B14_1015_enBE_dsk_full_y2 cc                42.047196           33.389356
#                           paypal            54.642967           65.210084
#                           rcc                2.083972            0.616246
#                           rpaypal            1.225866            0.784314
# all                       cc                41.834593           32.141952
#                           paypal            54.415057           66.197719
#                           rcc                2.120067            0.849176
#                           rpaypal            1.630283            0.811153
#
#                                    total_amount  ave_amount_ro
# B14_1015_enBE_dsk_full_nn cc           15388.37      12.493369
#                           paypal       19119.42       8.672505
#                           rcc            135.08       8.442500
#                           rpaypal        142.32       5.692800
# B14_1015_enBE_dsk_full_y  cc           25120.03      12.009398
#                           paypal       29979.29       8.033336
#                           rcc            335.76       5.439000
#                           rpaypal        148.30       3.802564
# B14_1015_enBE_dsk_full_y1 cc           16040.78      11.840522
#                           paypal       19372.96       7.916281
#                           rcc            233.73       5.843250
#                           rpaypal        104.97       4.198800
# B14_1015_enBE_dsk_full_y2 cc            9079.25      12.299877
#                           paypal       10606.33       8.244199
#                           rcc            102.03       3.822000
#                           rpaypal         43.33       3.095000
# all                       cc           40508.40      12.180247
#                           paypal       49098.71       8.280523
#                           rcc            470.84       6.167121
#                           rpaypal        290.62       4.540938

# %%
t.rate_stats( "B14_1015_enBE_dsk_full_nn", "B14_1015_enBE_dsk_full_y1", "B14_1015_enBE_dsk_full_y2", plot = True)
# Out:
#                            P(Winner)        Winners Lift                    CI
# B14_1015_enBE_dsk_full_y1          1      (0.00%, 0.00%)  (0.002371, 0.002541)
# B14_1015_enBE_dsk_full_nn        NaN  (191.18%, 221.77%)  (0.000774, 0.000832)
# B14_1015_enBE_dsk_full_y2        NaN  (204.76%, 242.06%)  (0.000726, 0.000796)

# %%
t.amount_stats('B14_1015_enBE_dsk_full_y', 'B14_1015_enBE_dsk_full_nn')
# Out:
# B14_1015_enBE_dsk_full_y gives between $4.3715 and $4.9509 more $/1000 impressions than B14_1015_enBE_dsk_full_nn

# %%
t.plot_impressions( stop = '2014-10-16 04:00',  smooth = 20)

# %%
t.compare_donation_amounts('B14_1015_enBE_dsk_full_y', 'B14_1015_enBE_dsk_full_nn' )

# %%
t.plot_utm_key(max_key = 5, normalize = True)

# %% [markdown]
# There was a bug in the banner code, so utm key is "always" 0.

# %%
t.plot_donations_over_time(smooth = 100, amount = False, stop = '2014-10-17 04:00')

# %% [markdown]
# We can see that the time of day changes the rate of donations per impression
