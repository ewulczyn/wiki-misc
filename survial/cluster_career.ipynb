# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import pandas as pd
pd.options.display.mpl_style = 'default'
from cluster  import query_career_cluster_data, query_monthly_behaviour_data, visualize_clustering 
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression 
from sklearn.svm import LinearSVC
from sklearn.preprocessing import StandardScaler
from time import time
import numpy as np
from sklearn import metrics
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.neighbors import KernelDensity
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
sns.set_palette("deep", desat=.6)
sns.set_context(rc={"figure.figsize": (8, 4)})

# %%
d_career = query_career_cluster_data()

# %%
d_career.to_csv('d_career_behaviour.csv', index = False)

# %%
d_career.head()
d_career['avg_monthly_edits_tot'] = d_career['avg_monthly_edits_tot'].astype(int)
print d_career.shape
print d_career.dtypes
# Out:
# (7346378, 15)
# avg_friend_count                float64
# avg_monthly_edits_0             float64
# avg_monthly_edits_1             float64
# avg_monthly_edits_2             float64
# avg_monthly_edits_3             float64
# avg_monthly_edits_tot             int64
# num_active_months                 int64
# percent_edits_got_archived_0    float64
# percent_edits_got_reverted_0    float64
# var_friend_count                float64
# var_monthly_edits_0             float64
# var_monthly_edits_1             float64
# var_monthly_edits_2             float64
# var_monthly_edits_3             float64
# var_monthly_edits_tot           float64
# dtype: object

# %%
n = 50000
df = d_career[:n]
df.head()
# Out:
#    avg_friend_count  avg_monthly_edits_0  avg_monthly_edits_1  \
# 0          0.000000        756513.411043         28637.907975
# 1          2.545455            70.986755             9.721854
# 2          0.000000            20.166667             4.000000
# 3          8.400000            29.463918            13.639175
# 4          0.000000             3.750000             0.250000
#
#    avg_monthly_edits_2  avg_monthly_edits_3  avg_monthly_edits_tot  \
# 0          6114.042945          8287.374233                 822761
# 1             1.834437             2.291391                     97
# 2             8.166667             0.666667                     36
# 3             3.907216            12.896907                     86
# 4             0.000000             0.000000                      4
#
#    num_active_months  percent_edits_got_archived_0  \
# 0                163                      0.031855
# 1                151                      0.041049
# ...

# %%
data = (df - df.mean()) / df.std()
data.head()
# Out:
#    avg_friend_count  avg_monthly_edits_0  avg_monthly_edits_1  \
# 0         -0.017343           221.354568           223.570759
# 1          0.813995             0.014442             0.069440
# 2         -0.017343            -0.000428             0.024769
# 3          2.726071             0.002292             0.100023
# 4         -0.017343            -0.005232            -0.004507
#
#    avg_monthly_edits_2  avg_monthly_edits_3  avg_monthly_edits_tot  \
# 0           141.021201           222.108944             221.672072
# 1             0.025493             0.048996               0.019560
# 2             0.171564             0.005449               0.003125
# 3             0.073308             0.333249               0.016596
# 4            -0.016824            -0.012419              -0.005497
#
#    num_active_months  percent_edits_got_archived_0  \
# 0          28.540279                     -0.450675
# 1          26.409198                     -0.426503
# ...

# %%
data = data.applymap(Math.log)
np.random.seed(42)
n_samples, n_features = data.shape
k_init = 3
k = 4

kmeans = KMeans(init='k-means++', n_clusters=k_init, n_init=10)
cluster_membership = pd.Series(kmeans.fit_predict(data))
visualize_clustering(data, k_init, kde = False)
# Out:
# [ 0.58224511  0.13524412]
# [[ 0.02001455  0.33395543  0.33400045  0.24620943  0.33388709  0.33463346
#    0.05502964 -0.00185744  0.0023154   0.02038762  0.33332771  0.33500941
#    0.21359561  0.32909114  0.33424871]
#  [-0.68532207  0.0383009   0.03631827  0.03935927 -0.02997131  0.03700694
#   -0.17049062  0.02625457 -0.09033795 -0.68375473  0.03617077  0.02766319
#    0.03012397 -0.11874949  0.03479135]]
